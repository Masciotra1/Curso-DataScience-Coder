# %% [markdown]
# <h1 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Predicción Ataque Cardíaco</h1>

# %% [markdown]
# <img src="https://elcomercio.pe/resizer/NyGC4JSreOBjxdQyb0P0gOstZcE=/580x330/smart/filters:format(jpeg):quality(75)/cloudfront-us-east-1.images.arcpublishing.com/elcomercio/SHCG3W2GI5DUHLTWRXU3JW4Z2I.jpg" alt="Bank Customer Churn" style="width:100%">

# %% [markdown]
# <h1 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Índice</h1>

# %% [markdown]
# <style>
#     ul {
#         list-style-type: none;
#         margin-left: 0;
#         padding-left: 0;
#     }
#
#     li {
#         margin-bottom: 8px;
#     }
#
#     .circle {
#         border-radius: 50%;
#         border: 1px solid green;
#         padding: 5px;
#         color: green;
#         display: inline-block;
#     }
#
#     .square {
#         border: 1px solid green;
#         padding: 5px;
#         color: green;
#         display: inline-block;
#     }
# </style>
#
# <ul>
#     <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Introduccion</u></li>
#     <ul style="padding-left:20px">
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Presentacion</u></li>
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Librerias</u></li>
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Importacion Dataset</u></li>
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Renombramos Variables</u></li>
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Columnas</u></li>
#     </ul>
#     <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Exploratory Data Analysis (EDA)</u></li>
#     <ul style="padding-left:20px">
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Renombramos Variables</u></li>
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Analisis de Variables</u></li>
#     </ul>
#     <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Variable Target</u></li>
#     <ul style="padding-left:20px">
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Information Value</u></li>
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Arbol de Decision</u></li>
#     </ul>
#     <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Regresion Logistica</u></li>
#     <ul style="padding-left:20px">
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Modelo 1</u></li>
#         <ul style="padding-left:20px">
#             <li><span class="square">&#9632;</span>&nbsp;<u style="color:green">Matriz de Confusion</u></li>
#             <li><span class="square">&#9632;</span>&nbsp;<u style="color:green">Metricas de Entrenamiento y Prueba</u></li>
#             <li><span class="square">&#9632;</span>&nbsp;<u style="color:green">K-Fold Cross-Validation - Validation Cruzada</u></li>
#             <li><span class="square">&#9632;</span>&nbsp;<u style="color:green">AUC - Curva ROC</u></li>
#         </ul>
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Modelo 2</u></li>
#         <ul style="padding-left:20px">
#             <li><span class="square">&#9632;</span>&nbsp;<u style="color:green">Matriz de Confusion</u></li>
#             <li><span class="square">&#9632;</span>&nbsp;<u style="color:green">Metricas de Entrenamiento y Prueba</u></li>
#             <li><span class="square">&#9632;</span>&nbsp;<u style="color:green">K-Fold Cross-Validation - Validacion Cruzada</u></li>
#             <li><span class="square">&#9632;</span>&nbsp;<u style="color:green">AUC - Curva ROC</u></li>
#         </ul>
#     </ul>
#     <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Random Forest</u></li>
#     <ul style="padding-left:20px">
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Modelo Random Forest</u></li>
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">AUC/ROC Random Forest</u></li>
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Validacion Cruzada Random Forest</u></li>
#     </ul>
#     <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Modelo KNN -K - Nearest Neighbors</u></li>
#     <ul style="padding-left:20px">
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Validacion Cruzada KNN -K- Nearest Neighbors</u></li>
#         <li><span class="circle">&#9679;</span>&nbsp;<u style="color:green">Conclusiones KNN - K-Nearest Neighbors</u></li>
#     </ul>
# </ul>

# %% [markdown]
# <h1 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Introducción</h1>

# %% [markdown]
# <span style="text-decoration: underline;">Presentacion</span>
#
# Hola!
#
# Esta dataSet "heart attack prediction", recopila mas de 8500 registros en 26 campos distintos. en este data se recopilan datos de pacientes con  distintas patologias de base como ser la diabetes, el consumo de alcohol, la hipertencion, entre otras.
# Lo que me motivo al elegir este proyecto es querer saber si existe relacion entre los distintos factores de salud y el "Riesgo Cardiaco."
#
# Este trabajo esta destinado a medicos y tecnicos de distintas areas del hospital a los que le pueda servir este analisis para entender la predisposicion de un paciente a pertener a un grupo de riesgo cardiaco
#
#
# deficinion de objetivo:
# queremos realizar un modelo predictivo que nos ayude a identificar que pacientes pertenecen al grupo de riesgo que identifica a los pacientes propensos a sufrir un ataque cardiaco.
#
# por las caracteristicas de nuestro dataset nos proponemos a desarrollar un modelo de <span style="text-decoration: underline; color: green;">Aprendizaje Supervisado Clasificación</span>
#
#
#
#
# Fuente:
# https://www.kaggle.com/datasets/iamsouravbanerjee/heart-attack-prediction-dataset?select=heart_attack_prediction_dataset.csv

# %% [markdown]
# <h1 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px;font-size:1.2em">Librerías</h1>

# %%
import pandas as pd
import numpy as np
import re 
import os

# Libreria para realizar graficos
import seaborn as sns
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
mpl.style.use("bmh")
# Para forwad selection
import sys
import joblib
sys.modules['sklearn.externals.joblib'] = joblib
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression
# Libreria para estimar regresión
import statsmodels.formula.api as sm
# Libreria para PCA
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
from sklearn import tree
from sklearn.tree import plot_tree
from statsmodels.api import OLS
import statsmodels.api as sm

# librerias para arboles de decision
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier

# librerias para regresion logistica
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report


# librerias para train y test
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score

# libreria de Confusion
from sklearn.metrics import confusion_matrix

# libreria K-Fold Cross-Validation - Cruzada
from sklearn.model_selection import StratifiedKFold, cross_val_score

# libreria AUC -Curva Roc
from sklearn.metrics import roc_curve, roc_auc_score

# librerias de Sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import auc
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import KernelPCA
from factor_analyzer import FactorAnalyzer
from sklearn.impute import SimpleImputer

# %% [markdown]
# <h1 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Importación de nuestro Conjunto de Datos</h1>

# %%
# importamos nuestro data set desde nuestro repositorio Github
url = "https://raw.githubusercontent.com/Masciotra1/Curso-DataScience-Coder/main/heart_attack_prediction_dataset.csv"
df = pd.read_csv(url, index_col=0, )

# convertiremos todos nuestros numeros a formato entero con 2 decimales
pd.options.display.float_format = '{:.2f}'.format

df.head()
# Out:
#             Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# Patient ID
# BMW7812      67    Male          208         158/88          72         0
# CZE1114      21    Male          389         165/93          98         1
# BNI9906      21  Female          324         174/99          72         1
# JLN3497      84    Male          383        163/100          73         1
# GFO8847      66    Male          318          91/88          93         1
#
#             Family History  Smoking  Obesity  Alcohol Consumption  ...  \
# Patient ID                                                         ...
# BMW7812                  0        1        0                    0  ...
# CZE1114                  1        1        1                    1  ...
# BNI9906                  0        0        0                    0  ...
# JLN3497                  1        1        0                    1  ...
# GFO8847                  1        1        1                    0  ...
#
# ...

# %% [markdown]
#  Vamos a generar un ID que sea numerico y correlativo

# %%
# Generar un ID en el DataFrame
df['ID'] = range(1, len(df) + 1)

# Establecer la columna 'ID' como el índice del DataFrame
df.set_index('ID', inplace=True)

# %%
#Descripción de las columnas
df.shape
# Out:
# (8763, 25)

# %% [markdown]
# <h1 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Vamos a renombrar nuestras variables</h1>

# %%
# Creamos un diccionario con las traducciones de las columnas
traducciones = {
    "Age": "Edad",
    "Sex": "Sexo",
    "Cholesterol": "Colesterol",
    "Blood Pressure": "Presion Sanguinea",
    "Heart Rate": "Pulso",
    "Diabetes": "Diabetes",
    "Family History": "Historial Familiar",
    "Smoking": "Fumador",
    "Obesity": "Obesidad",
    "Alcohol Consumption": "Consumo de Alcohol",
    "Exercise Hours Per Week": "Horas de Ejercicio por Semana",
    "Diet": "Dieta",
    "Previous Heart Problems": "Problemas Cardiacos Previos",
    "Medication Use": "Uso de Medicamentos",
    "Stress Level": "Nivel de Estres",
    "Sedentary Hours Per Day": "Horas Sedentarias por Dia",
    "Income": "Ingresos",
    "BMI": "BMI",
    "Triglycerides": "Trigliceridos",
    "Physical Activity Days Per Week": "Dias de Actividad Fisica por Semana",
    "Sleep Hours Per Day": "Horas de Sueño por Dia",
    "Country": "Pais",
    "Continent": "Continente",
    "Hemisphere": "Hemisferio",
    "Heart Attack Risk": "Riesgo Cardiaco"
}

# Renombramos las columnas del DataFrame
df.rename(columns=traducciones, inplace=True)

# %% [markdown]
# <h1 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Columna</h1>

# %% [markdown]
# <ul>
#     <li><b><u>ID:</u></b> Numero de paciente</li>
#     <li><b><u>Edad:</u></b> Variable cuantitativa - Edad de los pacientes</li>
#     <li><b><u>Sexo:</u></b> Variable cualitativa - genero de la persona</li>
#     <li><b><u>Colesterol:</u></b> Variable cuantitativa - sustancia que en valores elevados favorece la obstruccion de la circulacion sanginea</li>
#     <li><b><u>Presion Sanguinea:</u></b> Variable cuantitativa - Fuerza con la que circula la sangre</li>
#     <li><b><u>Pulso:</u></b> Variable cuantitativa - Frecuencia del latido del corazon</li>
#     <li><b><u>Diabetes:</u></b> Variable Binaria - Enfermedad metabolica</li>
#      <li><b><u>Historia Familiar:</u></b> Variable Binaria - Antecedentes familiares</li>
#     <li><b><u>Fumador:</u></b> Variable Binaria - es considerado una enfermedad</li>
#     <li><b><u>Obesidad:</u></b> Variable Binaria - representa el exceso de peso en una persona</li>
#     <li><b><u>Consumo de alcohol:</u></b> Variable Binaria - ingesta de alcohol</li>
#     <li><b><u>Horas de Ejercicio por Semana:</u></b> Variable cuantitativa -</li>
#     <li><b><u>Dieta:</u></b> Variable Categorica - se refleja el tipo de alimentacion de cada paciente.</li>
#     <li><b><u>BMI:</u></b> Variable cuantitativa - refleja el indice de masa corporal</li>
#     <li><b><u>Problemas Cardiacos Previos:</u></b> Variable Binaria - </li>
#     <li><b><u>Uso de Medicamentos:</u></b> Variable Binaria - </li>
#     <li><b><u>Nivel de Estres:</u></b> Variable Cuantitativa - </li>
#     <li><b><u>Horas Sedentarias por Dia:</u></b> Variable Cuantitativa - </li>
#     <li><b><u>ingresos:</u></b> Variable Cuantitativa - </li>
#     <li><b><u>Trigliceridos:</u></b> Variable Cuantitativa - </li>
#     <li><b><u>Dias de Actividad Fisica por Semana:</u></b> Variable Cuantitativa - </li>
#     <li><b><u>Horas de Sueño por Dia:</u></b> Variable Cuantitativa - </li>
#     <li><b><u>Pais:</u></b> Variable cualitativa - </li>
#     <li><b><u>Continente:</u></b> Variable cualitativa - </li>
#     <li><b><u>Hemisferio:</u></b> Variable cualitativa - </li>
#     <li><b><u>Riesgo Cardiaco:</u></b> Variable Target - Binaria.</li>
# </ul>

# %% [markdown]
# <h1 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Exploración y Análisis de Datos (EDA)</h1>

# %% [markdown]
# <h2 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Missing Data</h2>

# %%
print(df.isnull().sum())
# Out:
# Edad                                   0
# Sexo                                   0
# Colesterol                             0
# Presion Sanguinea                      0
# Pulso                                  0
# Diabetes                               0
# Historial Familiar                     0
# Fumador                                0
# Obesidad                               0
# Consumo de Alcohol                     0
# Horas de Ejercicio por Semana          0
# Dieta                                  0
# Problemas Cardiacos Previos            0
# Uso de Medicamentos                    0
# Nivel de Estres                        0
# Horas Sedentarias por Dia              0
# Ingresos                               0
# BMI                                    0
# Trigliceridos                          0
# Dias de Actividad Fisica por Semana    0
# Horas de Sueño por Dia                 0
# Pais                                   0
# Continente                             0
# ...

# %% [markdown]
# *Como se puede observar, el conjunto de datos no presenta ningún valor nulo en sus registros.*

# %%
#Examinemos algunos datos generales de los campos numéricos.
print(df.describe())
# Out:
#          Edad  Colesterol   Pulso  Diabetes  Historial Familiar  Fumador  \
# count 8763.00     8763.00 8763.00   8763.00             8763.00  8763.00
# mean    53.71      259.88   75.02      0.65                0.49     0.90
# std     21.25       80.86   20.55      0.48                0.50     0.30
# min     18.00      120.00   40.00      0.00                0.00     0.00
# 25%     35.00      192.00   57.00      0.00                0.00     1.00
# 50%     54.00      259.00   75.00      1.00                0.00     1.00
# 75%     72.00      330.00   93.00      1.00                1.00     1.00
# max     90.00      400.00  110.00      1.00                1.00     1.00
#
#        Obesidad  Consumo de Alcohol  Horas de Ejercicio por Semana  \
# count   8763.00             8763.00                        8763.00
# mean       0.50                0.60                          10.01
# std        0.50                0.49                           5.78
# ...

# %% [markdown]
# No tenemos valores nulos ni atipicos.

# %% [markdown]
# <u><span style="color:green">Resumen de nuestro DataSet</span></u>
#
# Nuestro dataset está compuesto por 25 variables y 8763 registros.

# %% [markdown]
# <h2 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Vamos a renombrar algunas de nuestras filas y columnas</h2>

# %% [markdown]
# <h2 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">De sexo renombramos Male y Female</h2>

# %%
# Renombrar los valores en la columna 'sexo'
df['Sexo'] = df['Sexo'].replace({'Male': 'Hombre', 'Female': 'Mujer'})

# %% [markdown]
# <h2 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Renombramos las filas de Dieta por: Promedio, Poco Saludable y Saludable</h2>

# %%
# Renombrar los valores en la columna 'Dieta'
df['Dieta'] = df['Dieta'].replace({'Average': 'Promedio', 'Unhealthy': 'Poco Saludable', 'Healthy': 'Saludable'})

# %% [markdown]
# <h3 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Vamos a cambiar el orden de algunas de nuestras variables. incluida nuestra variable Target</h3>

# %%
columnas_a_mover = df[["Diabetes", "Fumador", "Obesidad", "Consumo de Alcohol"]]

# Luego, eliminas estas columnas del DataFrame original
df.drop(["Diabetes", "Fumador", "Obesidad", "Consumo de Alcohol"], axis=1, inplace=True)

# Finalmente, insertas las columnas en las nuevas posiciones
nuevas_posiciones = 2  # Ubicación deseada para las columnas
for col in columnas_a_mover.columns:
    df.insert(nuevas_posiciones, col, columnas_a_mover[col])
    
# Guarda la columna "Riesgo Cardiaco" que deseas mover al principio
riesgo_cardiaco = df["Riesgo Cardiaco"]

# Elimina la columna "Riesgo Cardiaco" del DataFrame original
df.drop("Riesgo Cardiaco", axis=1, inplace=True)

# Inserta la columna "Riesgo Cardiaco" en la primera posición
df.insert(0, "Riesgo Cardiaco", riesgo_cardiaco)

# %% [markdown]
# <h2 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Análisis de nuestras variables</h2>

# %% [markdown]
# <h3 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Vamos a distribuir de otra forma la informacion contenida dentro de nuestras variables.</h3>

# %%
# Definir los límites de cada grupo
bins = [18, 45, 72, 99]

# Etiquetas para cada grupo
labels = ['18-45', '46-72', '73-99']

# Crear la columna 'Grupo_Edad' utilizando pd.cut()
df['Grupo_Edad'] = pd.cut(df['Edad'], bins=bins, labels=labels, right=True)

# %%
# Definir los límites de los rangos de colesterol
bins = [float('-inf'), 200, 239, float('inf')]

# Definir las etiquetas para los rangos de colesterol
labels = ['Normal', 'Alto', 'Muy alto']

# Crear una nueva columna en el DataFrame que contenga los grupos de colesterol
df['Grupo_Colesterol'] = pd.cut(df['Colesterol'], bins=bins, labels=labels, right=True)

# %%
# Definir los límites de los rangos de pulso
bins = [float('-inf'), 60, 100, float('inf')]

# Definir las etiquetas para los rangos de pulso
labels = ['Bajo', 'Normal', 'Alto']

# Crear una nueva columna en el DataFrame que contenga las categorías de pulso
df['Categoria_Pulso'] = pd.cut(df['Pulso'], bins=bins, labels=labels, right=True)

# %%
# Definir los límites de los rangos de BMI
bins = [float('-inf'), 18.5, 24.9, float('inf')]

# Definir las etiquetas para los rangos de BMI
labels = ['Peso insuficiente', 'Peso saludable', 'Sobrepeso']

# Crear una nueva columna en el DataFrame que contenga las categorías de BMI
df['Categoria_BMI'] = pd.cut(df['BMI'], bins=bins, labels=labels, right=True)

# %% [markdown]
# Vamos a realizar un grafico de Barras para ver como se ven nuestras principales variables

# %%
# Definir una paleta de colores de tonos de azul oscuro
paleta_azul_oscuro = sns.color_palette("Blues_d", n_colors=10)

# Lista de las variables que deseas visualizar
variables = ["Grupo_Edad", "Sexo", "Grupo_Colesterol", "Categoria_Pulso", "Diabetes", "Fumador", "Obesidad", "Consumo de Alcohol", "Dieta", "Categoria_BMI", ]

# Crear una figura y ejes para los subplots
fig, axs = plt.subplots(4, 3, figsize=(15, 15))

# Iterar sobre las variables y graficarlas en los subplots
for i, variable in enumerate(variables):
    fila = i // 3
    columna = i % 3
    # Obtener la cuenta de valores y sus índices
    valores, conteos = df[variable].value_counts().index, df[variable].value_counts().values
    # Graficar cada barra con un color de la paleta de colores y bordes negros
    for j, valor in enumerate(valores):
        axs[fila, columna].bar(valor, conteos[j], color=paleta_azul_oscuro[j], edgecolor='black')
    axs[fila, columna].set_title(variable)

# Ajustar los espacios entre los subplots
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Histograma de la variable "Edad"
plt.figure(figsize=(8, 6))
plt.hist(df["Edad"], bins=10, color='skyblue', edgecolor='black')  # Puedes ajustar el número de bins según tu preferencia
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.title("Histograma de Edad")
plt.grid(True)
plt.show()

# %%
# Histograma de la variable "Colesterol"
plt.figure(figsize=(8, 6))
plt.hist(df["Colesterol"], bins=10, color='skyblue', edgecolor='black')  # Puedes ajustar el número de bins según tu preferencia
plt.xlabel("Colesterol")
plt.ylabel("Frecuencia")
plt.title("Histograma de Colesterol")
plt.grid(True)
plt.show()

# %%
# Histograma de la variable "BMI"
plt.figure(figsize=(8, 6))
plt.hist(df["BMI"], bins=10, color='skyblue', edgecolor='black')  # Puedes ajustar el número de bins según tu preferencia
plt.xlabel("BMI")
plt.ylabel("Frecuencia")
plt.title("Histograma de Índice de Masa Corporal (BMI)")
plt.grid(True)
plt.show()

# %%
# Establecer el tamaño del gráfico
plt.figure(figsize=(10, 6))

# Crear el boxplot
sns.boxplot(x='Sexo', y='Edad', data=df)

# Personalizar el gráfico
plt.xlabel('Sexo', fontsize=14)
plt.ylabel('Edad', fontsize=14)
plt.title('Distribución de Edades por Sexo', fontsize=16)

# Mostrar el gráfico
plt.show()

# %%
plt.figure()
sns.catplot(data = df,
           kind="violin",
           x="Dieta",
           y="Riesgo Cardiaco",
           hue="Sexo",
           split=True)

# %% [markdown]
# <h2 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Mi Variable Target "Riesgo Cardiaco" esta compuesta de la siguiente forma</h2>

# %%
# Contar los valores de cada categoría de "Riesgo Cardiaco"
conteo_riesgo = df['Riesgo Cardiaco'].value_counts()

# Crear el gráfico de barras
conteo_riesgo.plot(kind='bar')

# Añadir etiquetas y título al gráfico
plt.xlabel('Categoría de Riesgo Cardiaco')
plt.ylabel('Cantidad')
plt.title('Distribución de Riesgo Cardiaco')

# Mostrar el gráfico
plt.show()

# %%
# Lista de las variables que deseas visualizar
variables = ["Grupo_Edad", "Sexo", "Grupo_Colesterol", "Categoria_Pulso", "Diabetes", "Fumador", "Obesidad", "Consumo de Alcohol", "Dieta", "Categoria_BMI", ]

# Definir el número de filas y columnas para el diseño del gráfico
num_filas = 4
num_columnas = 3

# Crear una figura y ejes para los subplots
fig, axs = plt.subplots(num_filas, num_columnas, figsize=(15, 15))

# Iterar sobre las variables y graficarlas en los subplots
for i, variable in enumerate(variables):
    fila = i // num_columnas
    columna = i % num_columnas
    # Crear un gráfico de barras para la variable actual comparando con "Riesgo Cardiaco"
    sns.countplot(data=df, x=variable, hue="Riesgo Cardiaco", ax=axs[fila, columna])
    axs[fila, columna].set_title(variable)

# Ajustar los espacios entre los subplots
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Lo que podemos ver en este ultimo grafico es que todas las variables tienen una relacion con la variable target que es muy parecida.

# %% [markdown]
# <h3 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Information Value</h3>

# %% [markdown]
# *Creemos una función que nos permita calcular el information value de cualquier variable que le propocionemos.*

# %%
def calculate_information_value(df, variable, target):
    """
    Calcula el Information Value (IV) para una variable dada en un DataFrame.

    Args:
    - df: DataFrame que contiene las variables de interés.
    - variable: Nombre de la variable independiente para la cual se calculará el IV.
    - target: Nombre de la variable dependiente (objetivo) binaria.

    Returns:
    - IV: Valor del Information Value para la variable dada.
    """

    # Agrupar la variable independiente en diferentes categorías
    grouped = df.groupby(variable)[target].agg(['count', 'sum'])

    # Calcular el porcentaje de eventos y no eventos en cada categoría
    grouped['event_rate'] = grouped['sum'] / grouped['count']
    grouped['non_event_rate'] = (grouped['count'] - grouped['sum']) / grouped['count']

    # Calcular el porcentaje de eventos acumulado y no eventos acumulado
    grouped['cum_event_rate'] = grouped['sum'].cumsum() / grouped['sum'].sum()
    grouped['cum_non_event_rate'] = (grouped['count'].cumsum() - grouped['sum'].cumsum()) / (grouped['count'].sum() - grouped['sum'].sum())

    # Calcular la diferencia entre el porcentaje de eventos acumulado y no eventos acumulado
    grouped['event_non_event_diff'] = grouped['cum_event_rate'] - grouped['cum_non_event_rate']

    # Calcular el Information Value sumando las diferencias ponderadas por la diferencia entre el porcentaje de eventos y no eventos acumulado
    iv = np.sum(grouped['event_non_event_diff'] * (grouped['cum_event_rate'] - grouped['cum_non_event_rate']))

    return iv

# %% [markdown]
# *Ahora pasemos todas nuestras variables por nuestra función y veamos los distintos IV de cada uno de ellas.*

# %%
# Crear un diccionario para almacenar los resultados
iv_results = {'Variable': [], 'IV': []}

# Lista de variables a analizar
variables_a_analizar = ['Edad', 'Sexo', 'Consumo de Alcohol', 'Obesidad',
       'Fumador', 'Diabetes', 'Colesterol', 'Pulso',
       'Historial Familiar', 'Horas de Ejercicio por Semana', 'Dieta',
       'Problemas Cardiacos Previos', 'Uso de Medicamentos', 'Nivel de Estres',
       'Horas Sedentarias por Dia', 'Ingresos', 'BMI', 'Trigliceridos',
       'Dias de Actividad Fisica por Semana', 'Horas de Sueño por Dia', 'Pais',
       'Continente', 'Hemisferio', 'Grupo_Edad', 'Grupo_Colesterol',
       'Categoria_Pulso', 'Categoria_BMI']  # Agrega aquí las variables que desees analizar

# Loop para calcular IV para cada variable
for variable in variables_a_analizar:
    iv_value = calculate_information_value(df, variable, "Riesgo Cardiaco")  # Utiliza la función calculate_information_value que definimos anteriormente
    iv_results['Variable'].append(variable)
    iv_results['IV'].append(iv_value)

# Crear el DataFrame a partir del diccionario
iv_results_df = pd.DataFrame(iv_results)

# Ordena el DataFrame por la columna "IV" en orden descendente (mayor IV primero)
iv_results_df = iv_results_df.sort_values(by='IV', ascending=False)

# Mostrar los resultados
iv_results_df
# Out:
#                                Variable   IV
# 9         Horas de Ejercicio por Semana 0.87
# 15                             Ingresos 0.54
# 16                                  BMI 0.37
# 14            Horas Sedentarias por Dia 0.36
# 17                        Trigliceridos 0.09
# 6                            Colesterol 0.05
# 0                                  Edad 0.00
# 7                                 Pulso 0.00
# 20                                 Pais 0.00
# 19               Horas de Sueño por Dia 0.00
# 18  Dias de Actividad Fisica por Semana 0.00
# 24                     Grupo_Colesterol 0.00
# 13                      Nivel de Estres 0.00
# 5                              Diabetes 0.00
# 23                           Grupo_Edad 0.00
# 21                           Continente 0.00
# 2                    Consumo de Alcohol 0.00
# 3                              Obesidad 0.00
# 26                        Categoria_BMI 0.00
# 22                           Hemisferio 0.00
# ...

# %% [markdown]
# Hemos corroborado lo que anteriormente se detecto en los gráficos, nuestras variables no tienen gran valor predictivo aun asi vamos a trabajar con las siguientes Variables: "Horas de Ejercicio por Semana","BMI","Salario","Horas Sedentarias por Dia",

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Árbol de decisión</h3>

# %%
# Obtener los valores únicos de la columna "Income"
valores_income = df['Ingresos'].unique()

# Mostrar la cantidad de valores únicos
print("Cantidad de valores únicos:", len(valores_income))

# Mostrar la información sobre los valores únicos
print("Información sobre los valores únicos:", valores_income)
# Out:
# Cantidad de valores únicos: 8615
# Información sobre los valores únicos: [261404 285768 235282 ...  36998 209943 247338]

# %%
# Contar cuántos valores son menores a 50000 en la columna "Income"
cantidad_menores_50000 = (df['Ingresos'] < 100000).sum()

# Mostrar el resultado
print("Cantidad de valores menores a 50000 en la columna 'Ingresos':", cantidad_menores_50000)
# Out:
# Cantidad de valores menores a 50000 en la columna 'Ingresos': 2572

# %%
# Genero predictores a usar
df['Horas de Ejercicio por Semana'] = df['Horas de Ejercicio por Semana'] < 6
df['Salario'] = df['Ingresos'] < 45000
df['BMI'] = df['BMI'] > 25
df['Sedentarismo Hora/Semana'] = df['Horas Sedentarias por Dia'] > 5


# Los enlisto: 
lista_predictores = ["Salario", "Horas de Ejercicio por Semana",'Sedentarismo Hora/Semana',"BMI"]

# Los transformo en matriz: 
X = df[lista_predictores].values

# %%
# Genero vector de target
y = df['Riesgo Cardiaco'].values

# %%
# Genero modelo: árbol de decisión 
clf = DecisionTreeClassifier(random_state = 1234, # Semilla aleatoria
                             criterion = 'gini', # Funcion para medir calidad de la división
                             splitter = 'best', # Estrategia para elegir la división de cada nodo
                             max_depth = 5, # Profundidad máxima del árbol
                             min_samples_leaf = 50 # Mínima cantidad de registros por nodo final
                            )
clf.feature_names = lista_predictores
model = clf.fit(X, y)

# %%
plt.figure(figsize=(24, 16))
plot_tree(clf, 
          filled = True, 
          rounded = True, 
          class_names = ["Sin Riesgo", "Con Riesgo"],
          feature_names = lista_predictores, 
          impurity = False,
          proportion = True,
          node_ids = True)
# Out:
# [Text(0.58, 0.9, 'node #0\nSalario <= 0.5\nsamples = 100.0%\nvalue = [0.642, 0.358]\nclass = Sin Riesgo'),
#  Text(0.32, 0.7, 'node #1\nBMI <= 0.5\nsamples = 90.9%\nvalue = [0.639, 0.361]\nclass = Sin Riesgo'),
#  Text(0.16, 0.5, 'node #2\nSedentarismo Hora/Semana <= 0.5\nsamples = 28.9%\nvalue = [0.628, 0.372]\nclass = Sin Riesgo'),
#  Text(0.08, 0.3, 'node #3\nHoras de Ejercicio por Semana <= 0.5\nsamples = 12.4%\nvalue = [0.621, 0.379]\nclass = Sin Riesgo'),
#  Text(0.04, 0.1, 'node #4\nsamples = 8.8%\nvalue = [0.624, 0.376]\nclass = Sin Riesgo'),
#  Text(0.12, 0.1, 'node #5\nsamples = 3.7%\nvalue = [0.615, 0.385]\nclass = Sin Riesgo'),
#  Text(0.24, 0.3, 'node #6\nHoras de Ejercicio por Semana <= 0.5\nsamples = 16.5%\nvalue = [0.633, 0.367]\nclass = Sin Riesgo'),
#  Text(0.2, 0.1, 'node #7\nsamples = 11.3%\nvalue = [0.631, 0.369]\nclass = Sin Riesgo'),
#  Text(0.28, 0.1, 'node #8\nsamples = 5.2%\nvalue = [0.637, 0.363]\nclass = Sin Riesgo'),
# ...

# %%
# Genero predicciones  
df['Predict_Arbol_Clase'] = clf.predict(df[lista_predictores])
df['Predict_Arbol_Nodo'] = clf.apply(df[lista_predictores])
# Out:
# C:\Users\Lean\anaconda3\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\Lean\anaconda3\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
df['Predict_Arbol_Clase'].value_counts()
# Out:
# 0    8763
# Name: Predict_Arbol_Clase, dtype: int64

# %%
df['Predict_Arbol_Nodo'].value_counts()
# Out:
# 14    2228
# 11    1581
# 7      992
# 15     933
# 4      768
# 12     688
# 8      452
# 5      322
# 25     212
# 20     150
# 26     142
# 24     135
# 21      86
# 19      74
# Name: Predict_Arbol_Nodo, dtype: int64

# %%
# Groupby por prediccion de clase: 
resultados = df.groupby('Predict_Arbol_Clase').agg(
    Cant = ('Predict_Arbol_Clase', 'count'),              
    Cant_RCardiaco = ('Riesgo Cardiaco', 'sum'),            
    Tasa_RCardiaco = ('Riesgo Cardiaco', 'mean')    
).reset_index()
resultados
# Out:
#    Predict_Arbol_Clase  Cant  Cant_RCardiaco  Tasa_RCardiaco
# 0                    0  8763            3139            0.36

# %% [markdown]
# *La predicción de nuestro árbol no logra reflejar con presicion la acertividad de nuestro modelo

# %%
# Groupby por prediccion de nodo
resultados_nodo = df.groupby('Predict_Arbol_Nodo').agg(     
    Cant=('Predict_Arbol_Nodo', 'count'),              
    Cant_RCardiaco=('Riesgo Cardiaco', 'sum'),            
    Tasa_RCardiaco1=('Riesgo Cardiaco', 'mean')    
).reset_index()

# Renombrar la columna Tasa_RCardiaco1 a Predict_Prob_Arbol
resultados_nodo.rename(columns={'Tasa_RCardiaco1': 'Predict_Prob_Arbol'}, inplace=True)

# Ordenar el DataFrame resultante
resultados_nodo_ordenado = resultados_nodo.sort_values(by='Predict_Prob_Arbol', ascending=False)
resultados_nodo_ordenado
# Out:
#     Predict_Arbol_Nodo  Cant  Cant_RCardiaco  Predict_Prob_Arbol
# 1                    5   322             124                0.39
# 0                    4   768             289                0.38
# 2                    7   992             366                0.37
# 4                   11  1581             578                0.37
# 7                   15   933             339                0.36
# 12                  25   212              77                0.36
# 3                    8   452             164                0.36
# 6                   14  2228             777                0.35
# 5                   12   688             238                0.35
# 13                  26   142              48                0.34
# 8                   19    74              25                0.34
# 11                  24   135              44                0.33
# 9                   20   150              47                0.31
# ...

# %%
# Genero la columna con la predicción 
df = df.merge(resultados_nodo[['Predict_Arbol_Nodo','Predict_Prob_Arbol']],
              left_on = 'Predict_Arbol_Nodo',
              right_on = 'Predict_Arbol_Nodo',
              how = 'left')
df.head(10)
# Out:
#    Riesgo Cardiaco  Edad    Sexo  Consumo de Alcohol  Obesidad  Fumador  \
# 0                0    67  Hombre                   0         0        1
# 1                0    21  Hombre                   1         1        1
# 2                0    21   Mujer                   0         0        0
# 3                0    84  Hombre                   1         0        1
# 4                0    66  Hombre                   0         1        1
# 5                1    54   Mujer                   1         0        1
# 6                1    90  Hombre                   1         0        1
# 7                1    84  Hombre                   1         1        1
# 8                0    20  Hombre                   0         1        1
# 9                0    43   Mujer                   1         1        1
#
#    Diabetes  Colesterol Presion Sanguinea  Pulso  ...           Hemisferio  \
# 0         0         208            158/88     72  ...  Southern Hemisphere
# ...

# %%
# Graficamente 
g1 = plt.figure()
sns.scatterplot(data=df,
                x=df.index,
                y='Predict_Prob_Arbol',  
                alpha=0.75,
                hue='Riesgo Cardiaco')
plt.show()

# %%
# Histogramas de predicción 
g1 = plt.figure()
sns.histplot(data = df,
             x = 'Predict_Prob_Arbol',  
             alpha = 0.5,
             hue = 'Riesgo Cardiaco',
             stat = 'probability', 
             bins = 4)
# Out:
# <Axes: xlabel='Predict_Prob_Arbol', ylabel='Probability'>

# %%
# Barplot por nodo 
resultados_nodo['Tasa_NoCliente'] = (1 - resultados_nodo['Predict_Prob_Arbol'])
sns.barplot(data = resultados_nodo,
            x = 'Predict_Arbol_Nodo',
            y = 'Predict_Prob_Arbol', 
            label = 'Porcentaje EsCliente',
            color = '#48E074')
sns.barplot(data=resultados_nodo, 
            x = 'Predict_Arbol_Nodo', 
            y = 'Tasa_NoCliente', 
            bottom=resultados_nodo['Predict_Prob_Arbol'], 
            label = 'Porcentaje No Es Cliente',
            color = '#E04848')
# Out:
# <Axes: xlabel='Predict_Arbol_Nodo', ylabel='Tasa_NoCliente'>

# %% [markdown]
#  * no se observa poder predictivo en ninguno de mis nodos.

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Regresión Logística</h3>

# %% [markdown]
# Dividamos la muestra en train y test. Mantendremos estas muestras separadas para todos los modelos que analizaremos.

# %%
df_train,df_test = train_test_split(df,
                                    test_size = 0.2, #Porcentaje de muestra test 
                                    random_state = 123) #Semilla

# %% [markdown]
# Corroboramos que ambas muestran tienen la misma tasa de retención.

# %%
# Check tasas similares 
print('Tasa RCardiaco TRAIN:')
print(round(df_train['Riesgo Cardiaco'].mean(),2))
print('Tasa RCardiaco TEST:')
print(round(df_test['Riesgo Cardiaco'].mean(),2))
# Out:
# Tasa RCardiaco TRAIN:
# 0.36
# Tasa RCardiaco TEST:
# 0.35

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Modelo 1</h3>

# %% [markdown]
# * Vamos a agregar algunas variables para realizar nuestra Regresion logistica.

# %%
# Predictores: 
lista_predictores = ['Edad', 'Pulso', 'Horas de Ejercicio por Semana',
       'Nivel de Estres', 'Horas Sedentarias por Dia', 'Salario']

#lista_predictores = ['Diabetes', 'Fumador', 'Obesidad', 'Consumo de Alcohol']

X_train = df_train[lista_predictores].values
y_train = df_train['Riesgo Cardiaco'].values
X_test = df_test[lista_predictores].values
y_test = df_test['Riesgo Cardiaco'].values

# Entrenar el modelo en el conjunto de entrenamiento
clf_1 = LogisticRegression()
clf_1.fit(X_train, y_train)

# Evaluar el modelo en el conjunto de prueba
y_pred = clf_1.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Precisión del modelo en el conjunto de prueba: {:.2f}%".format(accuracy * 100))

# Obtener las probabilidades predichas en lugar de las etiquetas de clase
y_prob_full = clf_1.predict_proba(df[lista_predictores])[:, 1]

# Agregar las probabilidades al DataFrame original
df['Probabilidad_Retencion_1'] = y_prob_full

# Obtener las probabilidades predichas en lugar de las etiquetas de clase
y_prob = clf_1.predict_proba(X_test)[:, 1]

print("Ajustemos el umbral para analizar posibles mejores resultados:")
# Ajustar el umbral que por defecto el algoritmo toma en 0.5
umbral = 0.4
y_pred_adjusted = (y_prob >= umbral).astype(int)

# Evaluar el modelo con el umbral ajustado
accuracy_adjusted = accuracy_score(y_test, y_pred_adjusted)
print("Precisión del modelo con umbral en {:.2f}: {:.2f}%".format(umbral, accuracy_adjusted * 100))

umbral = 0.6
y_pred_adjusted = (y_prob >= umbral).astype(int)

# Evaluar el modelo con el umbral ajustado
accuracy_adjusted = accuracy_score(y_test, y_pred_adjusted)
print("Precisión del modelo con umbral en {:.2f}: {:.2f}%".format(umbral, accuracy_adjusted * 100))
# Out:
# Precisión del modelo en el conjunto de prueba: 65.09%
# Ajustemos el umbral para analizar posibles mejores resultados:
# Precisión del modelo con umbral en 0.40: 65.09%
# Precisión del modelo con umbral en 0.60: 65.09%
# C:\Users\Lean\anaconda3\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Modelo 1 - Matriz de Confusión</h3>

# %%
# Calcular la matriz de confusión para el conjunto de entrenamiento
confusion_train = confusion_matrix(y_train, clf_1.predict(X_train))

# Calcular la matriz de confusión para el conjunto de prueba
confusion_test = confusion_matrix(y_test, clf_1.predict(X_test))

# Imprimir las matrices de confusión
print("Matriz de Confusión para Datos de Entrenamiento:")
print(confusion_train)

print("Matriz de Confusión para Datos de Prueba:")
print(confusion_test)
# Out:
# Matriz de Confusión para Datos de Entrenamiento:
# [[4483    0]
#  [2527    0]]
# Matriz de Confusión para Datos de Prueba:
# [[1141    0]
#  [ 612    0]]

# %%
# Grafico
# Primero defino la estructura de mis gráficos a mostras
fig, ax = plt.subplots(nrows = 1,
                      ncols = 2,
                      figsize = (10,5)) 

# Luego indico lo que voy a dibujar en el primer cuadrante
sns.heatmap(confusion_test, 
            annot=True, fmt='d', cmap='Greens', cbar=False, 
            ax=ax[0])
ax[0].set_title('Testeo')
ax[0].set_xlabel('Predicción')
ax[0].set_ylabel('Real')

# Luego indico lo que voy a dibujar en el segundo cuadrante
sns.heatmap(confusion_train, 
            annot=True, fmt='d', cmap='Blues', cbar=False, 
            ax=ax[1])
ax[1].set_title('Entrenamiento')
ax[1].set_xlabel('Predicción')
ax[1].set_ylabel('Real')

# Muestra
plt.show()

# %% [markdown]
# <div style="color: orange;">
#
# En el conjunto de testeo:
# El modelo no ha encontrado verdaderos positivos ni falsos negativos.
# Se observan 612 falsos positivos, lo que significa que 612 pacientes fueron incorrectamente clasificados como positivos.
# Por otro lado, se encontraron 1141 verdaderos negativos, lo que significa que 1141 pacientes de la clase negativa fueron correctamente identificados.
#
#
# En el conjunto de entrenamiento:
# El modelo no encontró verdaderos positivos ni falsos negativos.
# Por otro lado, encontró 2527 falsos positivos, lo que significa que fueron incorrectamente clasificados como positivos, y por otro lado, encontró 4483 verdaderos negativos, lo que significa que estos pacientes de la clase negativa fueron correctamente clasificados.
#
# El modelo tiene un alto número de falsos positivos. Esto sugiere que tiene dificultades para distinguir entre las clases.
#
# </div>

# %%
# Calculemos las metricas, para eso vamos a guardar el resultado de cada cuadrante para utilizarlos 

# Paso 1: capturo cada uno de los elementos de la matriz de confusión 
Total_TEST = sum(sum(confusion_test))
Total_TRAIN = sum(sum(confusion_train))
TP_TEST = confusion_test[1,1]
TP_TRAIN = confusion_train[1,1]
TN_TEST = confusion_test[0,0]
TN_TRAIN = confusion_train[0,0]
FP_TEST = confusion_test[0,1]
FP_TRAIN = confusion_train[0,1]
FN_TEST = confusion_test[1,0]
FN_TRAIN = confusion_train[1,0]

# Paso 2: Calculo métricas
Precision_TEST = TP_TEST / (TP_TEST + FP_TEST)
Precision_TRAIN = TP_TRAIN / (TP_TRAIN + FP_TRAIN)
Recall_TEST = TP_TEST / (TP_TEST + FN_TEST)
Recall_TRAIN = TP_TRAIN / (TP_TRAIN + FN_TRAIN)
Accuracy_TEST = (TP_TEST + TN_TEST) / Total_TEST
Accuracy_TRAIN = (TP_TRAIN + TN_TRAIN) / Total_TRAIN
Especificidad_TEST = TN_TEST / (TN_TEST + FP_TEST)
Especificidad_TRAIN = TN_TRAIN / (TN_TRAIN + FP_TRAIN)

# Paso 3: Presento todo en una misma tabla 
metricas = pd.DataFrame(columns=['Poblacion', 'Metrica','Valor'])

# Precision
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Precision',
              'Valor': Precision_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Precision',
              'Valor': Precision_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Recall
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Recall',
              'Valor': Recall_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Recall',
              'Valor': Recall_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Accurancy
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Accuracy',
              'Valor': Accuracy_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Accuracy',
              'Valor': Accuracy_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Especificidad
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Especificidad',
              'Valor': Especificidad_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Especificidad',
              'Valor': Especificidad_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Paso 4: Grafico 
plt.figure(figsize=(12, 5))
sns.barplot(data = metricas,
                x = 'Metrica',
                y = 'Valor',
                hue = 'Poblacion')
plt.xlabel('Tipo de Métrica')
plt.ylabel('Valor de la Métrica')
plt.title('Métricas - MODELO 1')
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(y_text,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')

plt.legend(loc='lower right')    
metricas_1 = plt.gcf()
plt.show()
# Out:
# C:\Users\Lean\AppData\Local\Temp\ipykernel_9604\2355489698.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   Precision_TEST = TP_TEST / (TP_TEST + FP_TEST)
# C:\Users\Lean\AppData\Local\Temp\ipykernel_9604\2355489698.py:17: RuntimeWarning: invalid value encountered in scalar divide
#   Precision_TRAIN = TP_TRAIN / (TP_TRAIN + FP_TRAIN)
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# <div style="color: orange;">
#
# En este modelo, la precisión y la sensibilidad (recall) son del 0%, lo que indica que el modelo no identifica correctamente ninguna de las clases. Aunque la precisión general es del 65% en test y 64% en train, esto es engañoso debido al desequilibrio de clases. La especificidad del 100% sugiere que el modelo es bueno para identificar la clase negativa pero falla en la clase positiva. Podríamos abordar el desequilibrio de clases y mejorar el rendimiento del modelo en la identificación de la clase positiva para obtener resultados más confiables.
#
# </div>

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Validación del Modelo 1</h3>

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Métricas de Entrenamiento y Prueba - Modelo 1</h3>

# %%
# Predecir en el conjunto de entrenamiento
y_train_pred = clf_1.predict(X_train)

# Calcular la precisión en el conjunto de entrenamiento
accuracy_train = accuracy_score(y_train, y_train_pred)

# Predecir en el conjunto de prueba
y_test_pred = clf_1.predict(X_test)

# Calcular la precisión en el conjunto de prueba
accuracy_test = accuracy_score(y_test, y_test_pred)

# Imprimir las métricas de precisión
print("Precisión en el conjunto de entrenamiento: {:.2f}%".format(accuracy_train * 100))
print("Precisión en el conjunto de prueba: {:.2f}%".format(accuracy_test * 100))
# Out:
# Precisión en el conjunto de entrenamiento: 63.95%
# Precisión en el conjunto de prueba: 65.09%

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">K-fold Cross-Validation - Validación Cruzada - Modelo 1</h3>

# %%
X = df[lista_predictores].values
y = df['Riesgo Cardiaco'].values

# Configurar K-fold Cross-Validation con 5 pliegues
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Realizar validación cruzada
cv_scores = cross_val_score(clf_1, X, y, cv=kfold, scoring='accuracy')

# Imprimir los resultados de la validación cruzada
print("Precisión de validación cruzada:")
for i, score in enumerate(cv_scores, start=1):
    print("Pliegue {}: {:.2f}%".format(i, score * 100))

print("\nPrecisión promedio: {:.2f}% (+/- {:.2f}%)".format(np.mean(cv_scores) * 100, np.std(cv_scores) * 100))
# Out:
# Precisión de validación cruzada:
# Pliegue 1: 64.18%
# Pliegue 2: 64.18%
# Pliegue 3: 64.18%
# Pliegue 4: 64.21%
# Pliegue 5: 64.16%
#
# Precisión promedio: 64.18% (+/- 0.02%)

# %% [markdown]
# La precisión en cada pliegue se mantiene en un rango estrecho entre el 64.18% y el 64.21%.

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">AUC - Curva ROC - Modelo 1</h3>

# %%
# Calcular la curva ROC y el AUC para el conjunto de prueba (test)
y_pred_prob_test = clf_1.predict_proba(X_test)[:, 1]  # Probabilidades de pertenecer a la clase positiva
fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_pred_prob_test)
roc_auc_test = roc_auc_score(y_test, y_pred_prob_test)

# %%
# Calcular la curva ROC y el AUC para el conjunto de entrenamiento (train)
y_pred_prob_train = clf_1.predict_proba(X_train)[:, 1]  # Probabilidades de pertenecer a la clase positiva
fpr_train, tpr_train, thresholds_train = roc_curve(y_train, y_pred_prob_train)
roc_auc_train = roc_auc_score(y_train, y_pred_prob_train)

# %%
# Crear el gráfico con ambas curvas ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr_test, tpr_test, color='darkorange', lw=2, label='Test ROC curve (AUC = %0.2f)' % roc_auc_test)
plt.plot(fpr_train, tpr_train, color='green', lw=2, label='Train ROC curve (AUC = %0.2f)' % roc_auc_train)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Un AUC de 0.49 no es bueno y sugiere que el modelo no tiene una capacidad sólida para distinguir entre las clases positivas y negativas. Cuanto más cercano esté el AUC a 1.0, mejor es la capacidad del modelo para clasificar correctamente las instancias de ambas clases. La consistencia entre el AUC del conjunto de prueba y el conjunto de entrenamiento sugiere que el modelo no generaliza bien.

# %%
# Crear un DataFrame con las predicciones y los valores reales

comparison_df = pd.DataFrame({'Real': y_test, 'Predicción': y_pred})

# Contar la cantidad de ocurrencias para cada clase
count_df = comparison_df.apply(pd.Series.value_counts).fillna(0)

# Graficar el resultado
fig, ax = plt.subplots(figsize=(8, 6))
bars = count_df.plot(kind='bar', ax=ax, color=['skyblue', 'orange'])

# Agregar etiquetas con los valores en las barras
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 10, round(yval), ha='center', va='bottom', fontsize=10, color='black')

ax.set_xticklabels(count_df.index, rotation=0)
ax.set_ylabel('Cantidad')
ax.set_title('Comparación entre Valores Reales y Predicciones - Modelo 1')
plt.show()

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Modelo 2</h3>

# %% [markdown]
# Para el siguiente modelo intentaremos mejorar nuestro modelo anterior agregando nuevas variables, como el cociente de las transacciones "Diabetes", "Fumador", "Obesidad", "Consumo de Alcohol".

# %%
# Predictores: 
lista_predictores_2 = ["Diabetes", "Fumador", "Obesidad", "Consumo de Alcohol"]

# Dividir los datos en conjunto de entrenamiento y conjunto de prueba (por ejemplo, 70% entrenamiento, 30% prueba)
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=422)
X_train = df_train[lista_predictores_2].values
y_train = df_train['Riesgo Cardiaco'].values
X_test = df_test[lista_predictores_2].values
y_test = df_test['Riesgo Cardiaco'].values

# Entrenar el modelo en el conjunto de entrenamiento
clf_2 = LogisticRegression()
clf_2.fit(X_train, y_train)

# Evaluar el modelo en el conjunto de prueba
y_pred = clf_2.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Precisión del modelo en el conjunto de prueba: {:.2f}%".format(accuracy * 100))

# Obtener las probabilidades predichas en lugar de las etiquetas de clase
y_prob_full = clf_2.predict_proba(df[lista_predictores_2])[:, 1]

# Agregar las probabilidades al DataFrame original
df['Probabilidad_Retencion_2'] = y_prob_full

# Obtener las probabilidades predichas en lugar de las etiquetas de clase
y_prob = clf_2.predict_proba(X_test)[:, 1]

print("Ajustemos el umbral para analizar posibles mejores resultados:")
# Ajustar el umbral que por defecto el algoritmo toma en 0.5
umbral = 0.4
y_pred_adjusted = (y_prob >= umbral).astype(int)

# Evaluar el modelo con el umbral ajustado
accuracy_adjusted = accuracy_score(y_test, y_pred_adjusted)
print("Precisión del modelo con umbral en {:.2f}: {:.2f}%".format(umbral, accuracy_adjusted * 100))

umbral = 0.6
y_pred_adjusted = (y_prob >= umbral).astype(int)

# Evaluar el modelo con el umbral ajustado
accuracy_adjusted = accuracy_score(y_test, y_pred_adjusted)
print("Precisión del modelo con umbral en {:.2f}: {:.2f}%".format(umbral, accuracy_adjusted * 100))
# Out:
# Precisión del modelo en el conjunto de prueba: 65.09%
# Ajustemos el umbral para analizar posibles mejores resultados:
# Precisión del modelo con umbral en 0.40: 65.09%
# Precisión del modelo con umbral en 0.60: 65.09%
# C:\Users\Lean\anaconda3\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# Hemos obtenido la misma predicción en nuestro nuevo modelo.

# %%
# Definir la cuadrícula de hiperparámetros a explorar
param_grid = {
    'fit_intercept' : [True,False],
    'penalty': ['l1', 'l2','elasticnet','none'],
    'C':[0.001, 0.005, 0.01, 0.1, 1, 10],
    'max_iter':[50,80,100],
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
}

# Inicializar el modelo de regresión logística
clf_Hiper = LogisticRegression()

# Realizar la búsqueda grid con la función de puntuación de especificidad
grid_search = GridSearchCV(clf_Hiper, param_grid, cv=3, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Mostrar los mejores hiperparámetros encontrados
print("Mejores hiperparámetros:", grid_search.best_params_)

# Obtener el mejor modelo
best_model = grid_search.best_estimator_

# Evaluar el mejor modelo en el conjunto de prueba
y_pred_best = best_model.predict(X_test)
accuracy_best = accuracy_score(y_test, y_pred_best)
print("Precisión del mejor modelo en el conjunto de prueba: {:.2f}%".format(accuracy_best * 100))
# Out:
# C:\Users\Lean\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1182: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\Lean\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1192: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Lean\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1182: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\Lean\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1192: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %% [markdown]
# *Hemos obtenido una mejor predicción en nuestro nuevo modelo, pero en este caso nuestro ajuste al umbral no mejora la predicción del algoritmo.*

# %%
# Definir la cuadrícula de hiperparámetros a explorar
param_grid = {
    'fit_intercept' : [True,False],
    'penalty': ['l1', 'l2','elasticnet','none'],
    'C':[0.001, 0.005, 0.01, 0.1, 1, 10],
    'max_iter':[50,80,100],
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
}

# Inicializar el modelo de regresión logística
clf_Hiper = LogisticRegression()

# Realizar la búsqueda grid con la función de puntuación de especificidad
grid_search = GridSearchCV(clf_Hiper, param_grid, cv=3, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Mostrar los mejores hiperparámetros encontrados
print("Mejores hiperparámetros:", grid_search.best_params_)

# Obtener el mejor modelo
best_model = grid_search.best_estimator_

# Evaluar el mejor modelo en el conjunto de prueba
y_pred_best = best_model.predict(X_test)
accuracy_best = accuracy_score(y_test, y_pred_best)
print("Precisión del mejor modelo en el conjunto de prueba: {:.2f}%".format(accuracy_best * 100))
# Out:
# C:\Users\Lean\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1182: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\Lean\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1192: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Lean\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1182: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\Lean\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1192: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Modelo 2 - Matriz de Confusión</h3>

# %%
# Calcular la matriz de confusión para el conjunto de entrenamiento
confusion_train = confusion_matrix(y_train, clf_2.predict(X_train))

# Calcular la matriz de confusión para el conjunto de prueba
confusion_test = confusion_matrix(y_test, clf_2.predict(X_test))

# Imprimir las matrices de confusión
print("Matriz de Confusión para Datos de Entrenamiento:")
print(confusion_train)

print("Matriz de Confusión para Datos de Prueba:")
print(confusion_test)
# Out:
# Matriz de Confusión para Datos de Entrenamiento:
# [[4483    0]
#  [2527    0]]
# Matriz de Confusión para Datos de Prueba:
# [[1141    0]
#  [ 612    0]]

# %%
# Grafico
# Primero defino la estructura de mis gráficos a mostras
fig, ax = plt.subplots(nrows = 1,
                      ncols = 2,
                      figsize = (10,5)) 

# Luego indico lo que voy a dibujar en el primer cuadrante
sns.heatmap(confusion_test, 
            annot=True, fmt='d', cmap='Greens', cbar=False, 
            ax=ax[0])
ax[0].set_title('Testeo')
ax[0].set_xlabel('Predicción')
ax[0].set_ylabel('Real')

# Luego indico lo que voy a dibujar en el segundo cuadrante
sns.heatmap(confusion_train, 
            annot=True, fmt='d', cmap='Blues', cbar=False, 
            ax=ax[1])
ax[1].set_title('Entrenamiento')
ax[1].set_xlabel('Predicción')
ax[1].set_ylabel('Real')

# Muestra
plt.show()

# %% [markdown]
# <div style="color: orange;">
# A pesar de que elegimos otras variables en nuestra lista de predictores en este modelo encontramos los mismos valores que en el modelo numero 1
#
# lista_predictores_2 = ["Diabetes", "Fumador", "Obesidad", "Consumo de Alcohol"]
#
#
#
# En el conjunto de testeo:
# El modelo no ha encontrado verdaderos positivos ni falsos negativos.
# Se observan 612 falsos positivos, lo que significa que 612 pacientes fueron incorrectamente clasificados como positivos.
# Por otro lado, se encontraron 1141 verdaderos negativos, lo que significa que 1141 pacientes de la clase negativa fueron correctamente identificados.
#
#
# En el conjunto de entrenamiento:
# El modelo no encontró verdaderos positivos ni falsos negativos.
# Por otro lado, encontró 2527 falsos positivos, lo que significa que fueron incorrectamente clasificados como positivos, y por otro lado, encontró 4483 verdaderos negativos, lo que significa que estos pacientes de la clase negativa fueron correctamente clasificados.
#
# El modelo tiene un alto número de falsos positivos. Esto sugiere que tiene dificultades para distinguir entre las clases.
#
# </div>

# %%
# Calculemos las metricas, para eso vamos a guardar el resultado de cada cuadrante para utilizarlos 

# Paso 1: capturo cada uno de los elementos de la matriz de confusión 
Total_TEST = sum(sum(confusion_test))
Total_TRAIN = sum(sum(confusion_train))
TP_TEST = confusion_test[1,1]
TP_TRAIN = confusion_train[1,1]
TN_TEST = confusion_test[0,0]
TN_TRAIN = confusion_train[0,0]
FP_TEST = confusion_test[0,1]
FP_TRAIN = confusion_train[0,1]
FN_TEST = confusion_test[1,0]
FN_TRAIN = confusion_train[1,0]

# Paso 2: Calculo métricas
Precision_TEST = TP_TEST / (TP_TEST + FP_TEST)
Precision_TRAIN = TP_TRAIN / (TP_TRAIN + FP_TRAIN)
Recall_TEST = TP_TEST / (TP_TEST + FN_TEST)
Recall_TRAIN = TP_TRAIN / (TP_TRAIN + FN_TRAIN)
Accuracy_TEST = (TP_TEST + TN_TEST) / Total_TEST
Accuracy_TRAIN = (TP_TRAIN + TN_TRAIN) / Total_TRAIN
Especificidad_TEST = TN_TEST / (TN_TEST + FP_TEST)
Especificidad_TRAIN = TN_TRAIN / (TN_TRAIN + FP_TRAIN)

# Paso 3: Presento todo en una misma tabla 
metricas = pd.DataFrame(columns=['Poblacion', 'Metrica','Valor'])

# Precision
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Precision',
              'Valor': Precision_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Precision',
              'Valor': Precision_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Recall
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Recall',
              'Valor': Recall_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Recall',
              'Valor': Recall_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Accurancy
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Accurancy',
              'Valor': Accuracy_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Accurancy',
              'Valor': Accuracy_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Especificidad
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Especificidad',
              'Valor': Especificidad_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Especificidad',
              'Valor': Especificidad_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Paso 4: Grafico 
plt.figure(figsize=(12, 5))
sns.barplot(data = metricas,
                x = 'Metrica',
                y = 'Valor',
                hue = 'Poblacion')
plt.xlabel('Tipo de Métrica')
plt.ylabel('Valor de la Métrica')
plt.title('Métricas - MODELO 1')
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(y_text,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')

plt.legend(loc='lower right')    
metricas_1 = plt.gcf()
plt.show()
# Out:
# C:\Users\Lean\AppData\Local\Temp\ipykernel_9604\2586480649.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   Precision_TEST = TP_TEST / (TP_TEST + FP_TEST)
# C:\Users\Lean\AppData\Local\Temp\ipykernel_9604\2586480649.py:17: RuntimeWarning: invalid value encountered in scalar divide
#   Precision_TRAIN = TP_TRAIN / (TP_TRAIN + FP_TRAIN)
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# <div style="color: orange;">
# A pesar de que elegimos otras variables en nuestra lista de predictores en este modelo encontramos los mismos valores que en el modelo numero 1. <br>
#
# lista_predictores_2 = ["Diabetes", "Fumador", "Obesidad", "Consumo de Alcohol"]. <br>
# En este modelo, la precisión y la sensibilidad (recall) son del 0%, lo que indica que el modelo no identifica correctamente ninguna de las clases. Aunque la precisión general es del 65% en test y 64% en train, esto es engañoso debido al desequilibrio de clases. La especificidad del 100% sugiere que el modelo es bueno para identificar la clase negativa pero falla en la clase positiva. Podríamos abordar el desequilibrio de clases y mejorar el rendimiento del modelo en la identificación de la clase positiva para obtener resultados más confiables.
#
# </div>

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Validación del Modelo 2</h3>

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Métricas de Entrenamiento y Prueba - Modelo 2</h3>

# %%
# Predecir en el conjunto de entrenamiento
y_train_pred = clf_2.predict(X_train)

# Calcular la precisión en el conjunto de entrenamiento
accuracy_train = accuracy_score(y_train, y_train_pred)

# Predecir en el conjunto de prueba
y_test_pred = clf_2.predict(X_test)

# Calcular la precisión en el conjunto de prueba
accuracy_test = accuracy_score(y_test, y_test_pred)

# Imprimir las métricas de precisión
print("Precisión en el conjunto de entrenamiento: {:.2f}%".format(accuracy_train * 100))
print("Precisión en el conjunto de prueba: {:.2f}%".format(accuracy_test * 100))
# Out:
# Precisión en el conjunto de entrenamiento: 63.95%
# Precisión en el conjunto de prueba: 65.09%

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">K-fold Cross-Validation - Validación Cruzada - Modelo 2</h3>

# %%
X = df[lista_predictores_2].values
y = df['Riesgo Cardiaco'].values

# Configurar K-fold Cross-Validation con 5 pliegues
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Realizar validación cruzada
cv_scores = cross_val_score(clf_2, X, y, cv=kfold, scoring='accuracy')

# Imprimir los resultados de la validación cruzada
print("Precisión de validación cruzada:")
for i, score in enumerate(cv_scores, start=1):
    print("Pliegue {}: {:.2f}%".format(i, score * 100))

print("\nPrecisión promedio: {:.2f}% (+/- {:.2f}%)".format(np.mean(cv_scores) * 100, np.std(cv_scores) * 100))
# Out:
# Precisión de validación cruzada:
# Pliegue 1: 64.18%
# Pliegue 2: 64.18%
# Pliegue 3: 64.18%
# Pliegue 4: 64.21%
# Pliegue 5: 64.16%
#
# Precisión promedio: 64.18% (+/- 0.02%)

# %% [markdown]
# <div style="color: orange;">
# El modelo numero 2 no demuestra una mejora con respecto al numero 1. a pesar de que se utilizaron otras variables como predictoras.
# </div>

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">AUC - Curva ROC - Modelo 2</h3>

# %%
# Calcular la curva ROC y el AUC para el conjunto de prueba (test)
y_pred_prob_test = clf_2.predict_proba(X_test)[:, 1]  # Probabilidades de pertenecer a la clase positiva
fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_pred_prob_test)
roc_auc_test = roc_auc_score(y_test, y_pred_prob_test)

# %%
# Calcular la curva ROC y el AUC para el conjunto de entrenamiento (train)
y_pred_prob_train = clf_2.predict_proba(X_train)[:, 1]  # Probabilidades de pertenecer a la clase positiva
fpr_train, tpr_train, thresholds_train = roc_curve(y_train, y_pred_prob_train)
roc_auc_train = roc_auc_score(y_train, y_pred_prob_train)

# %%
# Crear el gráfico con ambas curvas ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr_test, tpr_test, color='darkorange', lw=2, label='Test ROC curve (AUC = %0.2f)' % roc_auc_test)
plt.plot(fpr_train, tpr_train, color='green', lw=2, label='Train ROC curve (AUC = %0.2f)' % roc_auc_train)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# <div style="color: orange;">
# Un AUC de 0.51 no es bueno y sugiere que el modelo no tiene una capacidad sólida para distinguir entre las clases positivas y negativas. Cuanto más cercano esté el AUC a 1.0, mejor es la capacidad del modelo para clasificar correctamente las instancias de ambas clases. La consistencia entre el AUC del conjunto de prueba y el conjunto de entrenamiento sugiere que el modelo no generaliza bien.
# <br>
# <br>
# El modelo 2 es muy parecido al modelo 1. tiene solo una diferencia de 0.02 con respecto a lo que arroja el modelo 2
#
#
# </div>

# %%
# Crear un DataFrame con las predicciones y los valores reales
comparison_df = pd.DataFrame({'Real': y_test, 'Predicción': y_pred})

# Contar la cantidad de ocurrencias para cada clase
count_df = comparison_df.apply(pd.Series.value_counts).fillna(0)

# Graficar el resultado
fig, ax = plt.subplots(figsize=(8, 6))
bars = count_df.plot(kind='bar', ax=ax, color=['skyblue', 'orange'])

# Agregar etiquetas con los valores en las barras
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 10, round(yval), ha='center', va='bottom', fontsize=10, color='black')

ax.set_xticklabels(count_df.index, rotation=0)
ax.set_ylabel('Cantidad')
ax.set_title('Comparación entre Valores Reales y Predicciones - Modelo 2')
plt.show()

# %% [markdown]
# <div style="color: orange;">
# Comparación y conclusiones:
# Prácticamente estamos hablando de los mismos resultados tanto en el Modelo 1 como en el Modelo 2, a pesar de que usamos variables distintas.
#
# La especificidad en ambos modelos es del 100% en ambos modelos, lo que significa que es capaz de identificar correctamente todas las instancias de la clase negativa; en otras palabras, no hay falsos positivos en la predicción.
#
# La validación cruzada de ambos modelos fue del 64.18%, lo que sugiere que es capaz de generalizar bien a datos no vistos.
#
# Ambos modelos muestran AUCs parecidos, siendo el modelo 2 de 0.51. Esto sugiere que tiene dificultades para distinguir entre las clases positivas y negativas. Su capacidad de discriminación es muy baja.
#
# En conclusión, nos vamos a quedar con el modelo número 2. Si bien los dos arrojan los mismos valores, es en este en el que encontramos una muy leve ventaja en su AUC.
# </div>

# %% [markdown]
# <h2 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">RandomForest</h3>

# %% [markdown]
# <div style="color: orange;">
# A Continuacion vamos a probar otro modelo. vamos a utilizar las siguientes variables: ["Salario",'Edad', 'Consumo de Alcohol', 'Obesidad', 'Fumador', 'Diabetes', 'Colesterol']. Vamos a excluir la variable Target "Riesgo Cardiaco"
# </div>

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">RandomForest Nuevo Modelo Ajustado</h3>

# %%
df = df.sample(frac = 1).reset_index(drop = True) #To shuffle data

lista_predictores_4 = ["Salario",'Edad', 'Consumo de Alcohol', 'Obesidad', 'Fumador', 'Diabetes', 'Colesterol']

X_train = df_train[lista_predictores_4].values
y_train = df_train['Riesgo Cardiaco'].values
X_test = df_test[lista_predictores_4].values
y_test = df_test['Riesgo Cardiaco'].values

# %%
imputer = SimpleImputer(strategy='mean')
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)


# Crear el modelo
rf_model = RandomForestClassifier(n_estimators = 200, 
                                  max_depth = 10,
                                  min_samples_leaf = 2,
                                  min_samples_split=10,
                                  max_features = 6,
                                  random_state = 43,
                                  criterion = 'entropy')

# Entrenar el modelo
rf_model.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = rf_model.predict(X_test)

df_test['RF_Predicted_Riesgo Cardiaco'] = y_pred

# Evaluar la precisión del modelo
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión del modelo de testeo: {accuracy * 100:.2f}%')

# Realizar predicciones en el conjunto de entrenamiento
y_pred_2 = rf_model.predict(X_train)

# Agregar las predicciones a los conjuntos de datos
df_train['RF_Predicted_Riesgo Cardiaco'] = y_pred_2

accuracy = accuracy_score(y_train, y_pred_2)
print(f'Precisión del modelo de entrenamiento: {accuracy * 100:.2f}%')

# Mostrar la matriz de confusión y el informe de clasificación
print('\nMatriz de Confusión:')
print(confusion_matrix(y_test, y_pred))

print('\nInforme de Clasificación:')
print(classification_report(y_test, y_pred))
# Out:
# Precisión del modelo de testeo: 64.40%
# Precisión del modelo de entrenamiento: 66.33%
#
# Matriz de Confusión:
# [[1121   20]
#  [ 604    8]]
#
# Informe de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.65      0.98      0.78      1141
#            1       0.29      0.01      0.02       612
#
#     accuracy                           0.64      1753
#    macro avg       0.47      0.50      0.40      1753
# weighted avg       0.52      0.64      0.52      1753

# %% [markdown]
# <div style="color: orange;">
# La precisión del modelo en testeo nos da un 64.40% y la de entrenamiento un 66.33%.
# <br>
# Este análisis nos quiere decir que en nuestro modelo de testeo, las muestras que predijo como positivas o negativas, el 64.40% fueron clasificadas correctamente.
# <br>
# <br>
#
# Mientras que en nuestro modelo de entrenamiento, el 66.33% de nuestros datos evaluados fueron predicciones correctas.
# </div>

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">AUC/ROC RandomForest</h3>

# %%
# Definir la función de especificidad
def specificity_score(y_true, y_pred):
    tn, fp, _, _ = confusion_matrix(y_true, y_pred).ravel()
    specificity = tn / (tn + fp)
    return specificity

# Realizar predicciones en el conjunto de entrenamiento
y_train_pred = rf_model.predict(X_train)
y_test_pred = rf_model.predict(X_test)

# Obtener las probabilidades predichas en lugar de las etiquetas de clase
y_train_prob = rf_model.predict_proba(X_train)[:, 1]
y_test_prob = rf_model.predict_proba(X_test)[:, 1]

# Calcular las métricas para el conjunto de entrenamiento
accuracy_train = accuracy_score(y_train, y_train_pred)
precision_train, recall_train, f1_train, _ = precision_recall_fscore_support(y_train, y_train_pred, average='binary')
specificity_train = specificity_score(y_train, y_train_pred)

# Calcular las métricas para el conjunto de prueba
accuracy_test = accuracy_score(y_test, y_test_pred)
precision_test, recall_test, f1_test, _ = precision_recall_fscore_support(y_test, y_test_pred, average='binary')
specificity_test = specificity_score(y_test, y_test_pred)

# Calcular las curvas ROC
fpr_train, tpr_train, _ = roc_curve(y_train, y_train_prob)
roc_auc_train = auc(fpr_train, tpr_train)

fpr_test, tpr_test, _ = roc_curve(y_test, y_test_prob)
roc_auc_test = auc(fpr_test, tpr_test)

# Mostrar las métricas
print('Métricas para el Conjunto de Entrenamiento:')
print(f'Precisión: {accuracy_train * 100:.2f}%')
print(f'Precision: {precision_train:.2f}')
print(f'Recall: {recall_train:.2f}')
print(f'Especificidad: {specificity_train:.2f}')
print(f'F1-Score: {f1_train:.2f}')
print(f'AUC/ROC: {roc_auc_train:.2f}')

print('\nMétricas para el Conjunto de Prueba:')
print(f'Precisión: {accuracy_test * 100:.2f}%')
print(f'Precision: {precision_test:.2f}')
print(f'Recall: {recall_test:.2f}')
print(f'Especificidad: {specificity_test:.2f}')
print(f'F1-Score: {f1_test:.2f}')
print(f'AUC/ROC: {roc_auc_test:.2f}')

# Graficar las curvas ROC
plt.figure(figsize=(10, 6))
plt.plot(fpr_train, tpr_train, color='darkorange', lw=2, label=f'Train ROC Curve (AUC = {roc_auc_train:.2f})')
plt.plot(fpr_test, tpr_test, color='darkgreen', lw=2, label=f'Test ROC Curve (AUC = {roc_auc_test:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curvas ROC para Train y Test')
plt.legend(loc='lower right')
plt.show()
# Out:
# Métricas para el Conjunto de Entrenamiento:
# Precisión: 66.33%
# Precision: 0.96
# Recall: 0.07
# Especificidad: 1.00
# F1-Score: 0.13
# AUC/ROC: 0.86
#
# Métricas para el Conjunto de Prueba:
# Precisión: 64.40%
# Precision: 0.29
# Recall: 0.01
# Especificidad: 0.98
# F1-Score: 0.02
# AUC/ROC: 0.49

# %% [markdown]
# <div style="color: orange;">
# Obtenemos un train de 0.86 y un test de 0.49.
#
# * El modelo se ajusta bien a los datos de entrenamiento y puede capturar los patrones presentes en ellos. pero hay una diferencia con el conjunto de entrenamiento y el de prueba. puede que este subajustado y que no este generalizando bien.
# </div>

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Validación Cruzada RandomForest</h3>

# %%
# Realizar validación cruzada
cv_scores = cross_val_score(rf_model, X_train, y_train, cv=5, scoring='roc_auc')

# Mostrar los puntajes de validación cruzada
print(f"Puntajes de Validación Cruzada: {cv_scores}")
print(f"Puntaje Promedio: {cv_scores.mean()}")

# Graficar las curvas ROC para el conjunto de entrenamiento y prueba
plt.figure(figsize=(10, 6))
plt.plot(fpr_train, tpr_train, color='darkorange', lw=2, label=f'Train ROC Curve (AUC = {roc_auc_train:.2f})')
plt.plot(fpr_test, tpr_test, color='darkgreen', lw=2, label=f'Test ROC Curve (AUC = {roc_auc_test:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curvas ROC para Train y Test')
plt.legend(loc='lower right')
plt.show()
# Out:
# Puntajes de Validación Cruzada: [0.52477565 0.52200625 0.49196552 0.53547387 0.50075765]
# Puntaje Promedio: 0.5149957872676005

# %% [markdown]
# <h2 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Conclusiones RandomForest</h2>

# %% [markdown]
# <div style="color: orange;">
# Validacion Cruzada. los valores de train son altos. y marcarian un buen modelo. pero los de test indicarian que posiblemente este subajustado
# </div>

# %% [markdown]
# <h2 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Modelo KNN - K-Nearest Neighbors</h2>

# %%
X_train = df_train[lista_predictores_4].values
y_train = df_train['Riesgo Cardiaco'].values
X_test = df_test[lista_predictores_4].values
y_test = df_test['Riesgo Cardiaco'].values

# Genero y entreno
knn_model = KNeighborsClassifier(n_neighbors = 5,
                            metric='euclidean')

# Entrenar el modelo
knn_model .fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_test_pred = knn_model.predict(X_test)
y_train_pred = knn_model.predict(X_train)

# Obtener las probabilidades predichas en lugar de las etiquetas de clase
y_test_prob = knn_model.predict_proba(X_test)[:, 1]
y_train_prob = knn_model.predict_proba(X_train)[:, 1]

# %%
# Calcular las métricas para el conjunto de entrenamiento
accuracy_train = accuracy_score(y_train, y_train_pred)
precision_train, recall_train, f1_train, _ = precision_recall_fscore_support(y_train, y_train_pred, average='binary')
specificity_train = specificity_score(y_train, y_train_pred)

# Calcular las métricas para el conjunto de prueba
accuracy_test = accuracy_score(y_test, y_test_pred)
precision_test, recall_test, f1_test, _ = precision_recall_fscore_support(y_test, y_test_pred, average='binary')
specificity_test = specificity_score(y_test, y_test_pred)

# Mostrar las métricas
print('Métricas para el Conjunto de Entrenamiento:')
print(f'Accuracy: {accuracy_train * 100:.2f}%')
print(f'Precision: {precision_train:.2f}')
print(f'Recall: {recall_train:.2f}')
print(f'Specificity: {specificity_train:.2f}')
print(f'F1-Score: {f1_train:.2f}')
print(f'AUC/ROC: {roc_auc_train:.2f}')

print('\nMétricas para el Conjunto de Prueba:')
print(f'Accuracy: {accuracy_test * 100:.2f}%')
print(f'Precision: {precision_test:.2f}')
print(f'Recall: {recall_test:.2f}')
print(f'Specificity: {specificity_test:.2f}')
print(f'F1-Score: {f1_test:.2f}')
print(f'AUC/ROC: {roc_auc_test:.2f}')
# Out:
# Métricas para el Conjunto de Entrenamiento:
# Accuracy: 72.62%
# Precision: 0.67
# Recall: 0.47
# Specificity: 0.87
# F1-Score: 0.55
# AUC/ROC: 0.86
#
# Métricas para el Conjunto de Prueba:
# Accuracy: 56.47%
# Precision: 0.33
# Recall: 0.24
# Specificity: 0.74
# F1-Score: 0.28
# AUC/ROC: 0.49

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Validación Cruzada KNN - K-Nearest Neighbors</h3>

# %%
# Realizar validación cruzada
cv_scores = cross_val_score(knn_model, X_train, y_train, cv=5, scoring='accuracy')

# Mostrar los puntajes de validación cruzada
print("Puntajes de Validación Cruzada:", cv_scores)
print("Puntaje Promedio:", cv_scores.mean())
# Out:
# Puntajes de Validación Cruzada: [0.57560628 0.56490728 0.58630528 0.58487874 0.57988588]
# Puntaje Promedio: 0.5783166904422254

# %%
# Graficar las curvas ROC
plt.figure(figsize=(10, 6))
plt.plot(fpr_train, tpr_train, color='darkorange', lw=2, label=f'Train ROC Curve (AUC = {roc_auc_train:.2f})')
plt.plot(fpr_test, tpr_test, color='darkgreen', lw=2, label=f'Test ROC Curve (AUC = {roc_auc_test:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curvas ROC para Train y Test')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# <div style="color: orange;">
# Accuracy: El modelo clasifica correctamente alrededor del 72.62% de todas las muestras del conjunto de entrenamiento. Precision: De todas las muestras que el modelo predijo como positivas, alrededor del 67% realmente son positivas. Es decir, cuando el modelo predice que un Paciente tiene "Riesgo Cardiaco", tiene una precisión del 67%. Recall: El modelo identifica correctamente alrededor del 47% de todas las muestras positivas reales en el conjunto de entrenamiento. Es decir, de todos los pacientes tienen "Riesgo Cardiaco", el modelo identifica correctamente al 47%. Specificity: El modelo identifica correctamente alrededor del 87% de todas las muestras negativas reales en el conjunto de entrenamiento. Es decir, de todos los Pacientes  que realmente no tienen "Riesgo cardiaco", el modelo identifica correctamente al 87%. F1-Score: Es una medida que combina precisión y recall en un solo valor. Un valor de 0.55 indica un buen equilibrio entre precisión y recall en el conjunto de entrenamiento. AUC/ROC: El área bajo la curva ROC es 0.86, lo que indica un buen rendimiento del modelo para distinguir entre las clases positivas y negativas en el conjunto de entrenamiento.
#
# Métricas para el Conjunto de Prueba:
#
# Accuracy: El modelo clasifica correctamente alrededor del 56.47% de todas las muestras del conjunto de prueba. Precision: De todas las muestras que el modelo predijo como positivas, alrededor del 33% realmente son positivas. Es decir, cuando el modelo predice que un Paciente tiene "Riesgo Cardiaco", tiene una precisión del 33%. Recall: El modelo identifica correctamente alrededor del 24% de todas las muestras positivas reales en el conjunto de prueba. Es decir, de todos los pacientes tienen "Riesgo Cardiaco", el modelo identifica correctamente al 74%. Specificity: El modelo identifica correctamente alrededor del 74% de todas las muestras negativas reales en el conjunto de prueba. Es decir, de todos los Pacientes qque realmente no tienen "Riesgo cardiaco", el modelo identifica correctamente al 74%. F1-Score: Es una medida que combina precisión y recall en un solo valor. Un valor de 0.28 indica un buen equilibrio entre precisión y recall en el conjunto de prueba. AUC/ROC: El área bajo la curva ROC es 0.49, lo que indica un buen rendimiento del modelo para distinguir entre las clases positivas y negativas en el conjunto de prueba.
#
# Puntajes de Validación Cruzada:
#
# Los puntajes de validación cruzada muestran la precisión del modelo en diferentes divisiones de los datos de entrenamiento. El puntaje promedio de validación cruzada es aproximadamente 0.57, lo que indica que el modelo no tiene un rendimiento consistente en diferentes divisiones de los datos de entrenamiento.
#
# En general, los resultados indican que el modelo KNN tiene un buen rendimiento en la clasificación de Pacientes  que tienen y no tienen Riesgo Cardiaco en el conjunto de entrenamiento y prueba, con un ligero sobreajuste observado en la especificidad del conjunto de prueba en comparación con el conjunto de entrenamiento. Además, el rendimiento del modelo es consistente en diferentes divisiones de los datos de entrenamiento según la validación cruzada.
#
# </div>

# %% [markdown]
# <h2 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Feature Engineering 2da Parte</h2>

# %% [markdown]
# Iniciemos una nueva etapa de Feature Engineering en busca de nuevas features que puedan ayudarnos con nuestro modelo. Para ello utilizaremos la aprendido en clase: Principal Component Analysis (PCA), Kernel PCA y Análisis Factorial.

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Principal Component Analysis (PCA)</h3>

# %%
# Inicio el objeto PCA
pca = PCA(4)
# Genero componentes con TRAIN
PCA_train = pca.fit_transform(X_train)
# Aplico a test
PCA_test = pca.transform(X_test)

# Almaceno en dataframe y presento
# Train
PCA_train = pd.DataFrame(data = PCA_train)
prefijo = "PC_"
PCA_train = PCA_train.add_prefix(prefijo)
# Test
PCA_test = pd.DataFrame(data = PCA_test)
prefijo = "PC_"
PCA_test = PCA_test.add_prefix(prefijo)
# ¿Qué generé?
PCA_train.head()
# Out:
#      PC_0   PC_1  PC_2  PC_3
# 0 -138.95 -27.26  0.24 -0.57
# 1   62.14  -3.99 -0.60 -0.15
# 2   44.23  22.07  0.30 -0.58
# 3    7.16   3.21 -0.24  0.77
# 4    7.22  19.21  0.31 -0.59

# %%
# Análisis de la varianza explicada para cada componente
varianza_explicada = pca.explained_variance_ratio_
componentes = PCA_train.columns

plt.bar(componentes, 
        varianza_explicada)
plt.xlabel('Componente Principal')
plt.ylabel('Varianza Explicada')
plt.title('Varianza Explicada por Componente Principal')
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(y_text * 100,2))}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.show()

# %% [markdown]
# Se utilizaron 4 componentes principales (PC) para el análisis de PCA.
#
# Se generaron componentes tanto para el conjunto de entrenamiento como para el conjunto de prueba.
#
# El gráfico de varianza explicada por cada componente muestra que el primer componente (PC_0) captura el 93.54% de la varianza, mientras que el segundo componente (PC_1) captura solo el 6.24%. Los componentes restantes (PC_2 y PC_3) no aportan varianza adicional. Esto sugiere que la mayoría de la variabilidad de los datos está capturada por el primer componente.

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Kernel PCA</h3>

# %%
# Inicio el objeto KPCA
Kpca = KernelPCA(n_components = 4, 
                 kernel = 'sigmoid', 
                 gamma = 0.2)
# Genero componentes con TRAIN
KPCA_train = Kpca.fit_transform(X_train)
# Aplico a test
KPCA_test = Kpca.transform(X_test)

# Almaceno en dataframe y presento
# Train
KPCA_train = pd.DataFrame(data = KPCA_train)
prefijo = "KPC_"
KPCA_train = KPCA_train.add_prefix(prefijo)
# Test
KPCA_test = pd.DataFrame(data = KPCA_test)
prefijo = "KPC_"
KPCA_test = KPCA_test.add_prefix(prefijo)
# ¿Qué generé?
KPCA_test.head()
# Out:
#    KPC_0  KPC_1  KPC_2  KPC_3
# 0   0.00   0.00   0.00   0.00
# 1   0.00   0.00   0.00   0.00
# 2   0.00   0.00   0.00   0.00
# 3   0.00   0.00   0.00   0.00
# 4   0.00   0.00   0.00   0.00

# %% [markdown]
# Se utilizaron 4 componentes principales kernelizados (KPC) utilizando una función de kernel sigmoidal con un parámetro gamma de 0.2.
#
# Al igual que en PCA, se generaron componentes tanto para el conjunto de entrenamiento como para el conjunto de prueba.

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Ánalisis Factorial</h3>

# %%
# Inicializar el analizador factorial con un número máximo de factores (puedes ajustar según sea necesario)
max_factors = len(lista_predictores_4) - 1  
fa = FactorAnalyzer(n_factors = max_factors, 
                    rotation = None)

# Ajustar el modelo al conjunto de datos
fa.fit(X_train)

# Obtener los valores propios (eigenvalues)
eigenvalues, _ = fa.get_eigenvalues()

# Crear el Scree Plot
plt.plot(np.arange(1, len(lista_predictores_4) + 1), eigenvalues, marker='o')
plt.title('Scree Plot')
plt.xlabel('Número de Factores')
plt.ylabel('Valor Propio')
plt.show()

# %% [markdown]
# Se utilizó un análisis factorial con un máximo de 7 factores (uno menos que el número de variables predictoras originales) para el análisis de AF.
#
# El scree plot muestra que los primeros 4 factores tienen valores propios (eigenvalues) superiores a 1, lo que sugiere que estos factores explican una cantidad significativa de varianza en los datos.

# %%
# Genero mi modelo 
n_factores = 4
fa = FactorAnalyzer(n_factors = n_factores, 
                    is_corr_matrix = False)
fa.fit(X_train)
# Out:
# FactorAnalyzer(n_factors=4, rotation_kwargs={})

# %%
# Obtenemos las cargas
cargas_factoriales = pd.DataFrame({'Features': lista_predictores_4})
cargas_factoriales_values = pd.DataFrame(fa.loadings_)
prefijo = "CargaFactorial_"
cargas_factoriales_values = cargas_factoriales_values.add_prefix(prefijo)
cargas_factoriales = pd.concat([cargas_factoriales,cargas_factoriales_values],axis = 1)
print("Cargas de los factores:")
cargas_factoriales
# Out:
# Cargas de los factores:
#              Features  CargaFactorial_0  CargaFactorial_1  CargaFactorial_2  \
# 0             Salario              0.00              0.01             -0.00
# 1                Edad              0.59             -0.14             -0.26
# 2  Consumo de Alcohol              0.02              0.01              0.02
# 3            Obesidad              0.01             -0.03              0.09
# 4             Fumador              0.70              0.12              0.17
# 5            Diabetes             -0.00             -0.00              0.06
# 6          Colesterol              0.01              0.31             -0.03
#
#    CargaFactorial_3
# 0             -0.03
# 1             -0.10
# 2              0.18
# 3             -0.12
# 4              0.11
# 5              0.00
# 6             -0.03

# %%
# Visualmente
cargas_factoriales_long = cargas_factoriales.melt(id_vars='Features', 
                                                  var_name='Factor', 
                                                  value_name='CargaFactorial')

sns.barplot(data = cargas_factoriales_long,
                x = 'Features',
                y = 'CargaFactorial',
                hue = 'Factor')

plt.title('Cargas Factoriales por Variable')
plt.xlabel('Cargas Factoriales')
plt.ylabel('Factores')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# Se obtuvieron las cargas factoriales para los 4 factores. Las cargas factoriales indican la correlación entre las variables originales y los factores latentes. Las variables con cargas factoriales más altas en un factor son las más relevantes para ese factor.

# %%
# Generamos dataframes con las puntuaciones de factores
# representan la contribución de cada observación (fila) en el conjunto de datos a los factores latentes. 
AF_train = pd.DataFrame(fa.transform(X_train))
prefijo = "AF_"
AF_train = AF_train.add_prefix(prefijo)
AF_test = pd.DataFrame(fa.transform(X_test))
AF_test = AF_test.add_prefix(prefijo)
AF_train.head()
# Out:
#    AF_0  AF_1  AF_2  AF_3
# 0 -0.43  0.69  0.25  0.10
# 1  0.07 -0.15  0.05  0.31
# 2  0.65 -0.33 -0.12 -0.05
# 3  0.23  0.05 -0.14 -0.02
# 4  0.58 -0.17 -0.13 -0.05

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Resultados en Graficos Factorial</h3>

# %% [markdown]
# Normalicemos la variable target

# %%
# Normalicemos el target 
y_train = df_train['Riesgo Cardiaco']
y_test = df_test['Riesgo Cardiaco']
# Calculo media y desvio
media = y_train.mean()
desvio = np.std(y_train, ddof = 0)
# Genero parámetros con train
df_train['Riesgo Cardiaco_Scaled'] = (df_train['Riesgo Cardiaco'] - media) / desvio
df_test['Riesgo Cardiaco_Scaled'] = (df_test['Riesgo Cardiaco'] - media) / desvio

# %%
# Features escaladas
df_train_scaled = pd.DataFrame(data = X_train)
prefijo = "Scaled_"
df_train_scaled.columns = lista_predictores_4
df_train_scaled.add_prefix(prefijo)
df_train_scaled = df_train_scaled.add_prefix(prefijo)
df_test_scaled = pd.DataFrame(data = X_test)
prefijo = "Scaled_"
df_test_scaled.columns = lista_predictores_4
df_test_scaled = df_test_scaled.add_prefix(prefijo)

# %%
# Uno todo a los dataframes originales
df_train = pd.concat([df_train,df_train_scaled,PCA_train,KPCA_train,AF_train],axis = 1)
df_test = pd.concat([df_test,df_test_scaled,PCA_test,KPCA_test,AF_test],axis = 1)

# %%
# PCA
plt.figure()
sns.scatterplot(data=df_train,
                x='PC_0',
                y='Riesgo Cardiaco_Scaled',
                label='PC_0',
                color='#34EB63',
                alpha=1)
sns.scatterplot(data=df_train,
                x='PC_1',
                y='Riesgo Cardiaco_Scaled',
                label='PC_1',
                color='#AACA0B',
                alpha=0.75)
sns.scatterplot(data=df_train,
                x='PC_2',
                y='Riesgo Cardiaco_Scaled',
                label='PC_2',
                color='#CA7F0B',
                alpha=0.6)
sns.scatterplot(data=df_train,
                x='PC_3',
                y='Riesgo Cardiaco_Scaled',
                label='PC_3',
                color='#CA0B0B',
                alpha=0.5)
plt.xlabel('Componente Principal')
plt.ylabel('Riesgo Cardiaco')
plt.title('Relación entre componentes y variable target')
plt.show()

# %%
# Sólo primeros dos componentes 
plt.figure()
sns.scatterplot(data = df_train,
                x = 'PC_0',
                y = 'Riesgo Cardiaco',
               label='PC_0', 
               color = '#34EB63',
                alpha = 1)
sns.scatterplot(data = df_train, 
                x = 'PC_1', 
                y = 'Riesgo Cardiaco', 
                label = 'PC_1', 
                color = '#AACA0B',
                alpha = 0.75)
plt.xlabel('Componente Principal')
plt.ylabel('Riesgo Cardiaco')
plt.title('Relación entre componentes y variable target')
# Out:
# Text(0.5, 1.0, 'Relación entre componentes y variable target')

# %%
# Correlación con el target 
variables_PCA = ['PC_0','PC_1','PC_2','PC_3','Riesgo Cardiaco_Scaled']
variables_final = lista_predictores_4 + variables_PCA
# Calculo matriz de correlación 
matriz_correlacion = df_train[variables_final].corr(method='pearson')
# Selecciono a la variable target para estudiar únicamente correlación con ella 
matriz_correlacion_target = matriz_correlacion['Riesgo Cardiaco_Scaled']
# Calculo valor absoluto, para extraer correlaciones más fuertes independientemente de su sentido 
matriz_correlacion_target = abs(matriz_correlacion_target)
# Menciono columnas que quiero excluir del análisis de correlación 
columnas_a_excluir = ['Riesgo Cardiaco_Scaled']
# Las excluyo del análisis
matriz_correlacion_target = matriz_correlacion_target.drop(columns=columnas_a_excluir, index=columnas_a_excluir)
# Ordeno de mayor a menor correlacion 
matriz_correlacion_target = matriz_correlacion_target.sort_values(ascending=False)
# Grafico el top 20 de variables más correlacionadas
matriz_correlacion_target_graficar = matriz_correlacion_target[0:20]
plt.figure(figsize=(10, 6))  # Tamaño de la figura
plt.barh(matriz_correlacion_target_graficar.index, 
         matriz_correlacion_target_graficar.values,
         color = '#A989D6')
plt.xlabel('Correlación')
plt.title('Correlación con Riesgo Cardiaco_Scaled')
plt.gca().invert_yaxis()  # Invertir el eje Y para mostrar la característica más relevante en la parte superior
plt.show()
# Out:
# C:\Users\Lean\AppData\Local\Temp\ipykernel_9604\1548300064.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matriz_correlacion = df_train[variables_final].corr(method='pearson')

# %%
# PCA
plt.figure()
sns.scatterplot(data = df_train,
                x = 'KPC_0',
                y = 'Riesgo Cardiaco_Scaled',
               label='KPC_0', 
               color = '#34EB63',
                alpha = 1)
sns.scatterplot(data = df_train, 
                x = 'KPC_1', 
                y = 'Riesgo Cardiaco_Scaled', 
                label = 'KPC_1', 
                color = '#AACA0B',
                alpha = 0.75)
sns.scatterplot(data = df_train, 
                x = 'KPC_2', 
                y = 'Riesgo Cardiaco_Scaled', 
                label = 'KPC_2', 
                color = '#CA7F0B',
                alpha = 0.6)
sns.scatterplot(data = df_train, 
                x = 'KPC_3', 
                y = 'Riesgo Cardiaco_Scaled', 
                label = 'KPC_3', 
                color = '#CA0B0B',
                alpha = 0.5)
plt.xlabel('Kernel - Componente Principal')
plt.ylabel('Riesgo Cardiaco')
plt.title('Relación entre componentes Kernel y variable target')
# Out:
# Text(0.5, 1.0, 'Relación entre componentes Kernel y variable target')

# %%
# Sólo primeros dos componentes 
plt.figure()
sns.scatterplot(data = df_train,
                x = 'KPC_0',
                y = 'Riesgo Cardiaco_Scaled',
               label='KPC_0', 
               color = '#34EB63',
                alpha = 1)
plt.xlabel('Kernel - Componente Principal')
plt.ylabel('Riesgo Cardiaco')
plt.title('Relación entre componentes Kernel y variable target')
# Out:
# Text(0.5, 1.0, 'Relación entre componentes Kernel y variable target')

# %%
# Correlación con el target 
variables_KPCA = ['KPC_0','KPC_1','KPC_2','KPC_3','Riesgo Cardiaco_Scaled']
variables_final = lista_predictores_4 + variables_KPCA
# Calculo matriz de correlación 
matriz_correlacion = df_train[variables_final].corr(method='pearson')
# Selecciono a la variable target para estudiar únicamente correlación con ella 
matriz_correlacion_target = matriz_correlacion['Riesgo Cardiaco_Scaled']
# Calculo valor absoluto, para extraer correlaciones más fuertes independientemente de su sentido 
matriz_correlacion_target = abs(matriz_correlacion_target)
# Menciono columnas que quiero excluir del análisis de correlación 
columnas_a_excluir = ['Riesgo Cardiaco_Scaled']
# Las excluyo del análisis
matriz_correlacion_target = matriz_correlacion_target.drop(columns=columnas_a_excluir, index=columnas_a_excluir)
# Ordeno de mayor a menor correlacion 
matriz_correlacion_target = matriz_correlacion_target.sort_values(ascending=False)
# Grafico el top 20 de variables más correlacionadas
matriz_correlacion_target_graficar = matriz_correlacion_target[0:20]
plt.figure(figsize=(10, 6))  # Tamaño de la figura
plt.barh(matriz_correlacion_target_graficar.index, 
         matriz_correlacion_target_graficar.values,
         color = '#A989D6')
plt.xlabel('Correlación')
plt.title('Correlación con Riesgo Cardiaco_Scaled')
plt.gca().invert_yaxis()  # Invertir el eje Y para mostrar la característica más relevante en la parte superior
plt.show()
# Out:
# C:\Users\Lean\AppData\Local\Temp\ipykernel_9604\3719024862.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matriz_correlacion = df_train[variables_final].corr(method='pearson')

# %%
#Relación entre PC_0 y KPC_0
plt.figure()
sns.scatterplot(data = df_train,
                x = 'PC_0',
                y = 'KPC_0',
                alpha = 0.6)
plt.xlabel('Factor 0')
plt.ylabel('Resto PC_0 Y KPC_0')
plt.title('Relación entre Componentes')
# Out:
# Text(0.5, 1.0, 'Relación entre Componentes')

# %%
# Factores
plt.figure()
sns.scatterplot(data = df_train,
                x = 'AF_0',
                y = 'Riesgo Cardiaco_Scaled',
               label='AF_0', 
               color = '#34EB63',
                alpha = 1)
sns.scatterplot(data = df_train, 
                x = 'AF_1', 
                y = 'Riesgo Cardiaco_Scaled', 
                label = 'AF_1', 
                color = '#AACA0B',
                alpha = 0.75)
sns.scatterplot(data = df_train, 
                x = 'AF_2', 
                y = 'Riesgo Cardiaco_Scaled', 
                label = 'AF_2', 
                color = '#CA7F0B',
                alpha = 0.6)
sns.scatterplot(data = df_train, 
                x = 'AF_3', 
                y = 'Riesgo Cardiaco_Scaled', 
                label = 'AF_3', 
                color = '#CA0B0B',
                alpha = 0.5)
plt.xlabel('Factores')
plt.ylabel('Riesgo Cardiaco')
plt.title('Relación entre Factores y variable target')
# Out:
# Text(0.5, 1.0, 'Relación entre Factores y variable target')

# %%
# Correlación con el target 
variables_AF = ['AF_0','AF_1','AF_2','AF_3','Riesgo Cardiaco_Scaled']
variables_final = lista_predictores_4 + variables_AF
# Calculo matriz de correlación 
matriz_correlacion = df_train[variables_final].corr(method='pearson')
# Selecciono a la variable target para estudiar únicamente correlación con ella 
matriz_correlacion_target = matriz_correlacion['Riesgo Cardiaco_Scaled']
# Calculo valor absoluto, para extraer correlaciones más fuertes independientemente de su sentido 
matriz_correlacion_target = abs(matriz_correlacion_target)
# Menciono columnas que quiero excluir del análisis de correlación 
columnas_a_excluir = ['Riesgo Cardiaco_Scaled']
# Las excluyo del análisis
matriz_correlacion_target = matriz_correlacion_target.drop(columns=columnas_a_excluir, index=columnas_a_excluir)
# Ordeno de mayor a menor correlacion 
matriz_correlacion_target = matriz_correlacion_target.sort_values(ascending=False)
# Grafico el top 20 de variables más correlacionadas
matriz_correlacion_target_graficar = matriz_correlacion_target[0:20]
plt.figure(figsize=(10, 6))  # Tamaño de la figura
plt.barh(matriz_correlacion_target_graficar.index, 
         matriz_correlacion_target_graficar.values,
         color = '#A989D6')
plt.xlabel('Correlación')
plt.title('Correlación con Riesgo Cardiaco_Scaled')
plt.gca().invert_yaxis()  # Invertir el eje Y para mostrar la característica más relevante en la parte superior
plt.show()
# Out:
# C:\Users\Lean\AppData\Local\Temp\ipykernel_9604\3542205977.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matriz_correlacion = df_train[variables_final].corr(method='pearson')

# %%
#Relación entre factores 
plt.figure()
sns.scatterplot(data = df_train,
                x = 'AF_0',
                y = 'AF_1',
                label = 'AF_1', 
               color = '#34EB63',
                alpha = 1)
sns.scatterplot(data = df_train, 
                x = 'AF_0', 
                y = 'AF_2', 
                label = 'AF_2', 
                color = '#CA7F0B',
                alpha = 0.6)
sns.scatterplot(data = df_train, 
                x = 'AF_0', 
                y = 'AF_3', 
                label = 'AF_3', 
                color = '#CA0B0B',
                alpha = 0.6)
plt.xlabel('Factor 0')
plt.ylabel('Resto Factores')
plt.title('Relación entre Factores')
# Out:
# Text(0.5, 1.0, 'Relación entre Factores')

# %% [markdown]
# <h3 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Conclusiones</h3>

# %% [markdown]
# El análisis de PCA sugiere que la mayoría de la variabilidad de los datos se puede capturar con solo el primer componente principal. Esto podría indicar que algunas de las variables originales son altamente correlacionadas.
#
# El análisis de KernelPCA y AF también proporciona información sobre la estructura de los datos y la relevancia de las variables originales en los nuevos componentes generados

# %% [markdown]
# <h2 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Conclusión Final</h2>

# %% [markdown]
# Basándonos en el análisis realizado y en los resultados obtenidos del modelo de RandomForest ajustado por hiperparámetros.

# %%
# Gráfico de comparación para el conjunto de entrenamiento
plt.figure(figsize=(10, 6))
plt.scatter(df_train.index, df_train['Riesgo Cardiaco'], color='blue', label='Real')
plt.scatter(df_train.index, df_train['RF_Predicted_Riesgo Cardiaco'], color='red', marker='x', label='Predicho')
plt.xlabel('Índice de Muestra')
plt.ylabel('Riesgo Cardiaco')
plt.title('Comparación entre Datos Reales y Predichos (Conjunto de Entrenamiento)')
plt.legend()
plt.show()

# Gráfico de comparación para el conjunto de prueba
plt.figure(figsize=(10, 6))
plt.scatter(df_test.index, df_test['Riesgo Cardiaco'], color='blue', label='Real')
plt.scatter(df_test.index, df_test['RF_Predicted_Riesgo Cardiaco'], color='red', marker='x', label='Predicho')
plt.xlabel('Índice de Muestra')
plt.ylabel('Riesgo Cardiaco')
plt.title('Comparación entre Datos Reales y Predichos (Conjunto de Prueba)')
plt.legend()
plt.show()

# %% [markdown]
# <h2 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Desempeño del modeo</h2>

# %% [markdown]
# <div style="color: orange;">
# El modelo RandomForest ajustado por hiperparámetros mostró una precisión del 66.33% en el conjunto de entrenamiento y del 64.43% en el conjunto de prueba. Estos resultados indican que, si bien el modelo no es perfecto, logra hacer predicciones al momento de predecir pacientes con Riesgo Cardiaco.
# </div>

# %% [markdown]
# <h2 style="font-family:Times;text-align:left;font-variant:small-caps;color:#FFFFFF;background-color:#006400;border-radius:8px">Conclusión </h2>

# %% [markdown]
# <div style="color: orange;">
# El trabajo realizado sirve para entender cómo el análisis de ciertas variables nos ayudan como predictivo a la hora de diagnosticar distintas patologías. si bien considero que aun se puede mejorar bastante, Fue una hermosa experiencia haberle dedicado horass armandolo y tratando de que quede lo mejor posible.
#
# Disfrute mucho la cursada Gracias Profe!
# </div>
